# %% [markdown]
# # Generalization
# # UNet with 3 encoder-decoder blocks trained on 80x80 CelebA images

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from skimage.metrics import peak_signal_noise_ratio
import matplotlib.pylab as plt
import matplotlib.colors as colors
import torch
from torch.utils.data import DataLoader

import os
import time                   
import sys
import argparse 

sys.path.insert(0, '../code') 
from network import UNet
from model_loader_func import load_UNet
from plotting_func import plot_many_denoised,  show_im_set, plot_single_im
from quality_metrics_func import calc_psnr, im_set_corr
from linear_approx import calc_jacobian, traj_projections
from inverse_tasks_func import synthesis
from algorithm_inv_prob import univ_inv_sol
from dataloader_func import add_noise_torch

# %matplotlib inline

# %%
print(torch.__version__)
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
device
# Out:
# 1.13.1+cpu
# device(type='cpu')

# %% [markdown]
# ## Load denoisers

# %%
## Load pretraiend denoisers 

denoisers_face = {}
# denoisers in group A are trained on one partision of the data which is non-overlapping with partision B
groups = ['A', 'B'] 
swap = False
training_data_name = 'no-overlap_40x40'

Ns = [10,100,1000, 10000,98489] #size of the dataset 

for group in groups: 
    print('loading group ' , group )
    denoisers_face[group] = {}
    if group == 'B': 
        swap = True
    for N in Ns:       
        start_time_total = time.time()        
        try: 
            denoisers_face[group][N] = load_UNet(
                           base_path = '../denoisers/UNet',
                           training_data_name= training_data_name, 
                           training_noise='0to255',
                           RF=90,
                           set_size=N, 
                           swap=swap);
        except FileNotFoundError: 
            pass 
        print("--- %s seconds ---" % (round(time.time() - start_time_total)))
# Out:
# loading group  A
# --- 0 seconds ---
# --- 0 seconds ---
# --- 0 seconds ---
# --- 0 seconds ---
# --- 0 seconds ---
# loading group  B
# --- 0 seconds ---
# --- 0 seconds ---
# --- 0 seconds ---
# --- 0 seconds ---
# --- 0 seconds ---

# %%
denoisers_face['A'].keys()
# Out:
# dict_keys([10, 100, 1000, 10000, 98489])

# %% [markdown]
# ## Load datasets

# %%
###### Before running this cell, down the dataset from ??? into the datasets/img_align_celeba/ folder.
###### Dataset consist of CelebA images cropped to 160x160 and then downsampled to 80x80.
###### The RGB channels have been averaged to create grayscale images 

train_face ={}
test_face = {}
train_face['A'] = {}
train_face['B'] ={}
test_face['B'] = {}
test_face['A'] = {}

Ns = [10,100,1000, 10000,98489]

data = torch.load('../datasets/merged_balanced_40x40.pt')
K = data.shape[2] 
print(data.shape)
for N in Ns:
    train_face['A'][N] = data[0:N]
    test_face['A'][N] = data[-N::]
    train_face['B'][N] = data[-N::]
    test_face['B'][N] = data[0:N]
# Out:
# torch.Size([196978, 1, 40, 40])

# %%
## rename N=98489 with N=100000 for ease of use later 
## Do not run this cell twice! 

denoisers_face['A'][100000] = denoisers_face['A'][98489]
del denoisers_face['A'][98489]   
denoisers_face['B'][100000] = denoisers_face['B'][98489]
del denoisers_face['B'][98489]  

train_face['A'][100000] = train_face['A'][98489]
del train_face['A'][98489]   
train_face['B'][100000] = train_face['B'][98489]
del train_face['B'][98489]  

test_face['A'][100000] = test_face['A'][98489]
del test_face['A'][98489]   
test_face['B'][100000] = test_face['B'][98489]
del test_face['B'][98489] 

Ns = list(denoisers_face['A'].keys())
print(Ns)
# Out:
# [10, 100, 1000, 10000, 100000]

# %%
show_im_set(train_face['A'][10][0:10], n_columns=10, label='example training images')

# %%
show_im_set(train_face['B'][10][0:10], n_columns=10, label='example training images')

# %% [markdown]
# # One shot denoising

# %%
## compute psnr on test and train sets as a function of train set size N
sig_range = torch.logspace(.3,2.4,15)
psnr_test = {}
psnr_train = {}
for group in groups: 
    psnr_test[group] = {}
    psnr_train[group] = {}
    for N in Ns: 
        ## train 
        data = train_face[group][N]
        if N <300: 
            data = torch.tile(data, dims=(int(300/N) , 1,1,1))
        else: 
            data = data[0:300]        

        loader = DataLoader(dataset=data, batch_size=300, shuffle=False)
        try:
            print(N)
            psnr_train[group][N] = calc_psnr(denoisers_face[group][N],loader,sig_range , device)
        except KeyError: 
            pass

        ## test 
        data = test_face[group][1000][0:300]    
        loader = DataLoader(dataset=data, batch_size=300, shuffle=False)    
        try: 
            psnr_test[group][N] = calc_psnr(denoisers_face[group][N],loader,sig_range, device)
        except KeyError: 
            pass
# Out:
# 10
# 100
# 1000
# 10000
# 100000
# 10
# 100
# 1000
# 10000
# 100000

# %%
## plot 
group = 'B'
f , axs = plt.subplots(1,2, figsize=(12,7), sharex = True, sharey=True)
plt.tight_layout()
x_axis = [ -10*np.log10( (float(std)/255)**2  ) for std in psnr_train[group][1000].keys()]

for N in [10,100,1000,10000, 100000]: 
    print(N)
    ## train 
    axs[0].plot(x_axis, [psnr_train[group][N][key] for key in psnr_train[group][N].keys()], 
                marker = '.',markersize = 10, alpha = 1,label = 'N: '+ str(N))

    ## test 
    axs[1].plot(x_axis, [psnr_test[group][N][key] for key in psnr_test[group][N].keys()], 
                marker = '.',markersize = 10,label = 'N: '+ str(N), alpha = 1)
for i in range(2):
    axs[i].set_xticks(x_axis);
    axs[i].set_xticklabels(np.round(x_axis).astype(int) ,rotation=90, fontsize=15)
    axs[i].set_xlim(-3, 45)
    
    axs[i].set_yticks(range(9,65,3) );    
    axs[i].set_yticklabels(range(9,65,3), fontsize=15);
    axs[i].set_ylim(9, 65)
    
    axs[i].grid(  linewidth=1);
    
    colormap = plt.cm.copper #nipy_spectral, Set1,Paired   
    plot_colors = [colormap(i) for i in np.linspace(0, 1,len(Ns)+1)]
    for k,j in enumerate(axs[i].lines):
        j.set_color(plot_colors[k])
axs[0].plot(x_axis, [ -10*np.log10( (std/255)**2  ) for std in sig_range/K ],linestyle = 'dotted', color='black')
axs[0].plot( [0,65],[0,65] ,'k--', alpha = .7, label = 'identity');
axs[1].plot( [0,65],[0,65] ,'k--', alpha = .7, label = 'identity');

axs[1].legend(fontsize = 15);
axs[0].set_title('Train', fontsize = 30)
axs[1].set_title('Test', fontsize = 30)
axs[0].set_xlabel('Input PSNR', fontsize = 15)
axs[0].set_ylabel('Output PSNR', fontsize = 15);
axs[1].set_xlabel('Input PSNR', fontsize = 15);
# Out:
# 10
# 100
# 1000
# 10000
# 100000

# %% [markdown]
# # denoise the same image once as the train image and once as the test image

# %%
### pick N 
N = 100000

# %%
### denoise the same test image with different levels of noise using denoisers in the same group 

all_train_A_denoised = {}
all_noisy = {}

n = 0 # im number (must be smaller than N)
im = test_face['A'][N][n:n+1]

sigmas = torch.tensor([0,10,50,150, 255])
with torch.no_grad():
    for s in sigmas:
        s = np.round(s.item())
        noisy , _ = add_noise_torch( im , s )
        all_noisy[s] = noisy
        denoised_im = noisy.to(device) - denoisers_face['A'][N](noisy.to(device)).detach()
        
        all_train_A_denoised[np.round(s/255, 3)] = denoised_im
        if N ==1:
            print('expected distance: ', str(s/255/80 ))
### plot
plot_many_denoised(im, all_noisy, all_train_A_denoised ,device, 
                   suptitle = 'same denoiser, diff noise levels ', 
                   label='sigma : ', train= False, vmin=0, vmax=1, im_size=3)
# Out:
# c:\Users\sylva\Documents\Python\Inria\.inria\lib\site-packages\skimage\metrics\simple_metrics.py:163: RuntimeWarning: divide by zero encountered in scalar divide
#   return 10 * np.log10((data_range ** 2) / err)

# %%
### Now the same image is a train image for denoisers in group B
### Performance on the same image when it is a train image 
all_train_A_denoised = {}
all_noisy = {}


sigmas = torch.tensor([0,10,50,150, 255])
with torch.no_grad():
    for s in sigmas:
        s = np.round(s.item())
        noisy , _ = add_noise_torch( im , s )
        all_noisy[s] = noisy
        denoised_im = noisy.to(device)-denoisers_face['B'][N](noisy.to(device)).detach()
        
        all_train_A_denoised[np.round(s/255, 3)] = denoised_im
        if N ==1:
            print('expected distance: ', str(s/255/80 ))
### plot
plot_many_denoised(im, all_noisy, all_train_A_denoised ,device, 
                   suptitle = 'same denoiser, diff noise levels ', 
                   label='sigma : ', train= True, vmin=0, vmax=1, im_size=3)

# %% [markdown]
# # Synthesis

# %% [markdown]
# # Compare samples from two sets of denoisers

# %%
# generate samples starting from all_interm_Ysme seed using both denoisers 
                                                                                                        
synth = synthesis() 
samples_faces = {}
all_interm_Ys = {}
seed = 0
for group in groups: 
    samples_faces[group] = {}
    all_interm_Ys[group] = {}
    for N in Ns: 
        torch.manual_seed(seed)
        sample, interm_Ys,all_sigs, all_means =univ_inv_sol(denoisers_face[group][N], 
                                                             x_c= torch.zeros(1,K,K),
                                                             task=synth,
                                                             device=device,
                                                             sig_0=1, 
                                                             sig_L=.1, 
                                                             h0=.01 , 
                                                             beta=.1 , 
                                                             freq=0,
                                                             seed = seed, 
                                                             init_im = train_face[group][N].mean(dim=0)+ torch.randn(1,K,K, device = device), 
                                                             init_noise_mean=0,
                                                             max_T=2000, 
                                                             fixed_h=False)

        samples_faces[group][N] = sample.detach()
        all_interm_Ys[group][N] = interm_Ys
# Out:
# -------- final sigma,  0.09928945451974869
# -------- final mean  0.3903343975543976
# -------- total number of iterations,  87 -------- average time per iteration (s),  0.0189
# -------- final sigma,  0.0984683632850647
# -------- final mean  0.364730566740036
# -------- total number of iterations,  87 -------- average time per iteration (s),  0.0184
# -------- final sigma,  0.09827563166618347
# -------- final mean  0.3789757788181305
# -------- total number of iterations,  87 -------- average time per iteration (s),  0.0181
# -------- final sigma,  0.09935782849788666
# -------- final mean  0.42458415031433105
# -------- total number of iterations,  77 -------- average time per iteration (s),  0.0188
# -------- final sigma,  0.09955552965402603
# -------- final mean  0.39332449436187744
# -------- total number of iterations,  73 -------- average time per iteration (s),  0.022
# -------- final sigma,  0.09983508288860321
# -------- final mean  0.4399048984050751
# -------- total number of iterations,  87 -------- average time per iteration (s),  0.0202
# -------- final sigma,  0.09369481354951859
# -------- final mean  0.4061952233314514
# -------- total number of iterations,  88 -------- average time per iteration (s),  0.0188
# -------- final sigma,  0.09672655910253525
# -------- final mean  0.3684178590774536
# -------- total number of iterations,  87 -------- average time per iteration (s),  0.0199
# -------- final sigma,  0.09481418877840042
# -------- final mean  0.3944395184516907
# -------- total number of iterations,  77 -------- average time per iteration (s),  0.0193
# -------- final sigma,  0.09292455017566681
# -------- final mean  0.38776475191116333
# -------- total number of iterations,  75 -------- average time per iteration (s),  0.0187

# %%
group = 'A'
show_im_set(torch.stack([v for k, v in samples_faces[group].items()]), label='',sub_labels= ['N='+str(N) for N in denoisers_face[group].keys()] , n_columns=5)
group = 'B'
show_im_set(torch.stack([v for k, v in samples_faces[group].items()]), label='',sub_labels= ['']*5 , n_columns=5)

# %%
closest_train = {}
for group in groups: 
    closest_train[group] = []
    for N in Ns:
        corrs = im_set_corr(samples_faces[group][N].unsqueeze(0).to(device), 
                            train_face[group][N].to(device), remove_mean=True)
        values, indices = corrs.max(dim = 1)
        closest_train[group].append(train_face[group][N][indices.cpu()])

# %%
plt.figure()
group = 'A'
show_im_set(torch.vstack(closest_train[group]), label='',sub_labels= ['N='+str(N) for N in denoisers_face[group].keys()] , n_columns=5)
show_im_set(torch.stack([v for k, v in samples_faces[group].items()]), label='',sub_labels= ['']*5, n_columns=5)

group = 'B'
show_im_set(torch.stack([v for k, v in samples_faces[group].items()]), label='',sub_labels= ['']*5 , n_columns=5)
show_im_set(torch.vstack(closest_train[group]), label='',sub_labels= ['']*5 , n_columns=5);

# %%
more_closest_train = {}
for group in groups: 
    more_closest_train[group] = [[] for _ in range(10)]
    for i in range(10):
        more_closest_train[group][i] = []
        for N in Ns:
            corrs = im_set_corr(samples_faces[group][N].unsqueeze(0).to(device), 
                            train_face[group][N].to(device), remove_mean=True)
            values, indices = corrs.topk(10, dim = 1)
            closest_img = train_face[group][N][indices[0, i].cpu()]
            value = values[0, i].cpu().item()
            more_closest_train[group][i].append((closest_img, value))

# %%
plt.figure()
group = 'A'
for i in reversed(range(10)):
    images = [item[0] for item in more_closest_train[group][i]]
    corrs = [f"{item[1]:.3f}" for item in more_closest_train[group][i]]
    show_im_set(torch.stack(images), label="'"*(i+1),sub_labels= corrs, n_columns=5)
show_im_set(torch.stack([v for k, v in samples_faces[group].items()]), label='samples from group A',sub_labels= ['']*5, n_columns=5)

group = 'B'
show_im_set(torch.stack([v for k, v in samples_faces[group].items()]), label='samples from group B',sub_labels= ['']*5 , n_columns=5)
for i in range(10):
    images = [item[0] for item in more_closest_train[group][i]]
    corrs = [f"{item[1]:.3f}" for item in more_closest_train[group][i]]
    show_im_set(torch.stack(images), label="'"*(i+1),sub_labels= corrs , n_columns=5)
# Out:
# c:\Users\sylva\Documents\Python\Inria\xp\notebooks\../code\plotting_func.py:427: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   f, axs = plt.subplots(n_rows, n_columns, figsize = (im_size * n_columns , im_size * n_rows))

# %%
from tqdm import tqdm
import lpips
loss_fn_alex = lpips.LPIPS(net='alex')
loss_fn_vgg = lpips.LPIPS(net='vgg')

def prep_for_lpips(img): # img: [1, H, W] in [0, 1] → returns [3, H, W] in [-1, 1]
    if img.max() > 1.1:
        img = img / 255.0
    img_rgb = img.expand(3, -1, -1)
    return img_rgb * 2 - 1
# Out:
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# c:\Users\sylva\Documents\Python\Inria\.inria\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\sylva\Documents\Python\Inria\.inria\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: c:\Users\sylva\Documents\Python\Inria\.inria\lib\site-packages\lpips\weights\v0.1\alex.pth
# Setting up [LPIPS] perceptual loss: trunk [vgg], v[0.1], spatial [off]
# c:\Users\sylva\Documents\Python\Inria\.inria\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: c:\Users\sylva\Documents\Python\Inria\.inria\lib\site-packages\lpips\weights\v0.1\vgg.pth

# %%
lpips_closest_train = {}
for group in groups: 
    lpips_closest_train[group] = [[] for _ in range(10)]
    for i in range(10):
        lpips_closest_train[group][i] = []
        for N in Ns:
            corrs = im_set_corr(samples_faces[group][N].unsqueeze(0).to(device), 
                            train_face[group][N].to(device), remove_mean=True)
            values, indices = corrs.topk(10, dim = 1)
            closest_img = train_face[group][N][indices[0, i].cpu()]
            value = values[0, i].cpu().item()
            lpips_closest_train[group][i].append((closest_img, value))

# %%
plt.figure()
group = 'A'

for i in reversed(range(10)):
    images = [item[0] for item in lpips_closest_train[group][i]]
    corrs = [f"{item[1]:.3f}" for item in lpips_closest_train[group][i]]

    samples = [samples_faces[group][N] for N in Ns]

    lpips_scores = []
    for gen_img, close_img in zip(samples, images):
        gen_ref   = prep_for_lpips(gen_img.cpu())
        close_rgb = prep_for_lpips(close_img.cpu())
        val = loss_fn_vgg(gen_ref.unsqueeze(0).to(device), close_rgb.unsqueeze(0).to(device))
        lpips_scores.append(f"{val.item():.3f}")

    show_im_set(torch.stack(images), label="'"*(i+1),sub_labels=[f"corr={c}\nlpips={l}" for c, l in zip(corrs, lpips_scores)], n_columns=5)

show_im_set(torch.stack([v for k, v in samples_faces[group].items()]), label='samples from group A',sub_labels= ['']*5, n_columns=5)

group = 'B'

show_im_set(torch.stack([v for k, v in samples_faces[group].items()]), label='samples from group B',sub_labels= ['']*5 , n_columns=5)

for i in range(10):
    images = [item[0] for item in lpips_closest_train[group][i]]
    corrs = [f"{item[1]:.3f}" for item in lpips_closest_train[group][i]]

    samples = [samples_faces[group][N] for N in Ns]

    lpips_scores = []
    for gen_img, close_img in zip(samples, images):
        gen_ref   = prep_for_lpips(gen_img.cpu())
        close_rgb = prep_for_lpips(close_img.cpu())
        val = loss_fn_vgg(gen_ref.unsqueeze(0).to(device), close_rgb.unsqueeze(0).to(device))
        lpips_scores.append(f"{val.item():.3f}")

    show_im_set(torch.stack(images), label="'"*(i+1),sub_labels = [f"corr={c}\nlpips={l}" for c, l in zip(corrs, lpips_scores)], n_columns=5)
# Out:
# c:\Users\sylva\Documents\Python\Inria\xp\notebooks\../code\plotting_func.py:427: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   f, axs = plt.subplots(n_rows, n_columns, figsize = (im_size * n_columns , im_size * n_rows))

# %%
#Generate many samples from a pair of denoisers trained on N images 
N = 100000
n_samples = 20
shift = 0
seeds = range(shift,shift+n_samples)
freq =10

all_samples = {}
all_interm_Ys = {}
all_sigmas={}
all_means = {}

start_time_total = time.time()
synth = synthesis()

for group in groups: 
    print('------------ group: ', group)
  
    all_samples[group] = torch.zeros(n_samples, 1, K,K).to(device)
    all_interm_Ys[group] = []
    all_sigmas[group] = []
    all_means[group] = [] 
    
    for n in range(n_samples): 
        print('--------- N : ', N)        
        torch.manual_seed(seeds[n])
        sample, interm_Ys,sigmas, means =univ_inv_sol(denoisers_face[group][N], 
                                                             x_c= torch.zeros(1,K,K),
                                                             task=synth,
                                                             device=device,
                                                             sig_0=1, 
                                                             sig_L=.1, 
                                                             h0=.01 , 
                                                             beta=.1 , 
                                                             freq=freq,
                                                             seed = seeds[n], 
                                                             init_im = train_face[group][N].mean(dim=0) + torch.randn(1,K,K, device = device), 
                                                             init_noise_mean=0,
                                                             max_T=10000, 
                                                             fixed_h=False)
        all_samples[group][n, 0] = sample.detach()
        all_interm_Ys[group].append(interm_Ys)
        all_sigmas[group].append(sigmas)
        all_means[group].append(means)
        
print("--- %s seconds ---" % (time.time() - start_time_total))
# Out:
# ------------ group:  A
# --------- N :  100000
# ----------------------------- 10
# sigma  1.1040719747543335
# mean  0.44114381074905396
# ----------------------------- 20
# sigma  0.9815011024475098
# mean  0.3515133261680603
# ----------------------------- 30
# sigma  0.7926464676856995
# mean  0.3554172217845917
# ----------------------------- 40
# sigma  0.516988217830658
# mean  0.3978028893470764
# ----------------------------- 50
# sigma  0.3547041118144989
# mean  0.4120473563671112
# ----------------------------- 60
# sigma  0.2188887596130371
# mean  0.3961617350578308
# ----------------------------- 70
# sigma  0.1204855889081955
# mean  0.3922981917858124
# -------- final sigma,  0.09955552965402603
# -------- final mean  0.39332449436187744
# -------- total number of iterations,  73 -------- average time per iteration (s),  0.0194
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0833076238632202
# mean  0.42617252469062805
# ----------------------------- 20
# sigma  1.019187569618225
# mean  0.48216646909713745
# ----------------------------- 30
# sigma  0.8341288566589355
# mean  0.4536709487438202
# ----------------------------- 40
# sigma  0.6340053081512451
# mean  0.4319601356983185
# ----------------------------- 50
# sigma  0.41842108964920044
# mean  0.4214150905609131
# ----------------------------- 60
# sigma  0.24008850753307343
# mean  0.405663400888443
# ----------------------------- 70
# sigma  0.1304994374513626
# mean  0.41256943345069885
# -------- final sigma,  0.09898914396762848
# -------- final mean  0.41246187686920166
# -------- total number of iterations,  74 -------- average time per iteration (s),  0.019
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0756328105926514
# mean  0.5040395259857178
# ----------------------------- 20
# sigma  0.9945105314254761
# mean  0.46533897519111633
# ----------------------------- 30
# sigma  0.782361626625061
# mean  0.3909429907798767
# ----------------------------- 40
# sigma  0.5255091190338135
# mean  0.3570612370967865
# ----------------------------- 50
# sigma  0.3089224100112915
# mean  0.350580632686615
# ----------------------------- 60
# sigma  0.19091658294200897
# mean  0.34348106384277344
# -------- final sigma,  0.0929596796631813
# -------- final mean  0.3542458713054657
# -------- total number of iterations,  69 -------- average time per iteration (s),  0.02
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0996222496032715
# mean  0.4179058372974396
# ----------------------------- 20
# sigma  0.9535347819328308
# mean  0.45773133635520935
# ----------------------------- 30
# sigma  0.7029200196266174
# mean  0.5350735187530518
# ----------------------------- 40
# sigma  0.48146742582321167
# mean  0.5712812542915344
# ----------------------------- 50
# sigma  0.3077729642391205
# mean  0.580752968788147
# ----------------------------- 60
# sigma  0.1538645178079605
# mean  0.5730032920837402
# -------- final sigma,  0.09178949892520905
# -------- final mean  0.5660215616226196
# -------- total number of iterations,  67 -------- average time per iteration (s),  0.019
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0356868505477905
# mean  0.36186036467552185
# ----------------------------- 20
# sigma  0.9149443507194519
# mean  0.35291123390197754
# ----------------------------- 30
# sigma  0.7144042253494263
# mean  0.38104546070098877
# ----------------------------- 40
# sigma  0.5052798390388489
# mean  0.3417227268218994
# ----------------------------- 50
# sigma  0.3071112632751465
# mean  0.3295856714248657
# ----------------------------- 60
# sigma  0.17935359477996826
# mean  0.30156785249710083
# -------- final sigma,  0.09934203326702118
# -------- final mean  0.31116658449172974
# -------- total number of iterations,  70 -------- average time per iteration (s),  0.0189
# --------- N :  100000
# ----------------------------- 10
# sigma  0.9906708598136902
# mean  0.4123852550983429
# ----------------------------- 20
# sigma  0.8650803565979004
# mean  0.4061030149459839
# ----------------------------- 30
# sigma  0.7616274356842041
# mean  0.39389702677726746
# ----------------------------- 40
# sigma  0.5376996994018555
# mean  0.35267409682273865
# ----------------------------- 50
# sigma  0.40185585618019104
# mean  0.32153618335723877
# ----------------------------- 60
# sigma  0.24230945110321045
# mean  0.32372376322746277
# ----------------------------- 70
# sigma  0.12988117337226868
# mean  0.31714144349098206
# -------- final sigma,  0.09778733551502228
# -------- final mean  0.3193976879119873
# -------- total number of iterations,  75 -------- average time per iteration (s),  0.0192
# --------- N :  100000
# ----------------------------- 10
# sigma  1.04665207862854
# mean  0.3957143723964691
# ----------------------------- 20
# sigma  0.8704645037651062
# mean  0.4364805519580841
# ----------------------------- 30
# sigma  0.6598783731460571
# mean  0.4846312701702118
# ----------------------------- 40
# sigma  0.497776597738266
# mean  0.5485545992851257
# ----------------------------- 50
# sigma  0.3228583037853241
# mean  0.5901631712913513
# ----------------------------- 60
# sigma  0.2001158744096756
# mean  0.5815230011940002
# ----------------------------- 70
# sigma  0.10548301041126251
# mean  0.5845947861671448
# -------- final sigma,  0.09585879743099213
# -------- final mean  0.5842977166175842
# -------- total number of iterations,  72 -------- average time per iteration (s),  0.0189
# --------- N :  100000
# ----------------------------- 10
# sigma  1.035245418548584
# mean  0.45764023065567017
# ----------------------------- 20
# sigma  0.89435875415802
# mean  0.35447078943252563
# ----------------------------- 30
# sigma  0.7798701524734497
# mean  0.3562246263027191
# ----------------------------- 40
# sigma  0.5189018845558167
# mean  0.31834572553634644
# ----------------------------- 50
# sigma  0.3315656781196594
# mean  0.3249198794364929
# ----------------------------- 60
# sigma  0.1824926733970642
# mean  0.3240668773651123
# -------- final sigma,  0.09180419892072678
# -------- final mean  0.32006919384002686
# -------- total number of iterations,  70 -------- average time per iteration (s),  0.0174
# --------- N :  100000
# ----------------------------- 10
# sigma  1.107304334640503
# mean  0.46742379665374756
# ----------------------------- 20
# sigma  0.9159492254257202
# mean  0.41952091455459595
# ----------------------------- 30
# sigma  0.7492635846138
# mean  0.44207724928855896
# ----------------------------- 40
# sigma  0.5223740339279175
# mean  0.41164693236351013
# ----------------------------- 50
# sigma  0.3670903444290161
# mean  0.4114902913570404
# ----------------------------- 60
# sigma  0.2068953514099121
# mean  0.40412628650665283
# ----------------------------- 70
# sigma  0.09309495985507965
# mean  0.40279144048690796
# -------- final sigma,  0.09309495985507965
# -------- final mean  0.4018104672431946
# -------- total number of iterations,  71 -------- average time per iteration (s),  0.0172
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0050445795059204
# mean  0.44207963347435
# ----------------------------- 20
# sigma  0.8600327372550964
# mean  0.43011173605918884
# ----------------------------- 30
# sigma  0.7408890724182129
# mean  0.4501068890094757
# ----------------------------- 40
# sigma  0.5456603169441223
# mean  0.5105008482933044
# ----------------------------- 50
# sigma  0.3660877048969269
# mean  0.5470038056373596
# ----------------------------- 60
# sigma  0.1982460767030716
# mean  0.5517989993095398
# -------- final sigma,  0.08825324475765228
# -------- final mean  0.5516851544380188
# -------- total number of iterations,  70 -------- average time per iteration (s),  0.0174
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0477831363677979
# mean  0.40782779455184937
# ----------------------------- 20
# sigma  0.9494904279708862
# mean  0.3901787996292114
# ----------------------------- 30
# sigma  0.7217265367507935
# mean  0.39207130670547485
# ----------------------------- 40
# sigma  0.5414784550666809
# mean  0.41826218366622925
# ----------------------------- 50
# sigma  0.3836612105369568
# mean  0.391367107629776
# ----------------------------- 60
# sigma  0.24270769953727722
# mean  0.38131725788116455
# ----------------------------- 70
# sigma  0.1336832195520401
# mean  0.3799339532852173
# -------- final sigma,  0.09688884764909744
# -------- final mean  0.38476791977882385
# -------- total number of iterations,  76 -------- average time per iteration (s),  0.0176
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0426788330078125
# mean  0.4021783471107483
# ----------------------------- 20
# sigma  0.9002307057380676
# mean  0.3958286941051483
# ----------------------------- 30
# sigma  0.7729257345199585
# mean  0.3981274366378784
# ----------------------------- 40
# sigma  0.5406533479690552
# mean  0.40657347440719604
# ----------------------------- 50
# sigma  0.33050745725631714
# mean  0.3781016170978546
# ----------------------------- 60
# sigma  0.1710519939661026
# mean  0.3610237240791321
# -------- final sigma,  0.09990186989307404
# -------- final mean  0.3463577330112457
# -------- total number of iterations,  68 -------- average time per iteration (s),  0.0173
# --------- N :  100000
# ----------------------------- 10
# sigma  0.9942099452018738
# mean  0.4045095443725586
# ----------------------------- 20
# sigma  0.8993194699287415
# mean  0.3955713212490082
# ----------------------------- 30
# sigma  0.6470833420753479
# mean  0.42227283120155334
# ----------------------------- 40
# sigma  0.500408947467804
# mean  0.3866346776485443
# ----------------------------- 50
# sigma  0.3246435821056366
# mean  0.37335968017578125
# ----------------------------- 60
# sigma  0.20579326152801514
# mean  0.37063589692115784
# ----------------------------- 70
# sigma  0.1133655458688736
# mean  0.3566582202911377
# -------- final sigma,  0.09270089119672775
# -------- final mean  0.35607776045799255
# -------- total number of iterations,  74 -------- average time per iteration (s),  0.017
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0843411684036255
# mean  0.4366925060749054
# ----------------------------- 20
# sigma  0.9052239656448364
# mean  0.47043198347091675
# ----------------------------- 30
# sigma  0.7214931845664978
# mean  0.4218476116657257
# ----------------------------- 40
# sigma  0.503271758556366
# mean  0.45096355676651
# ----------------------------- 50
# sigma  0.3525811433792114
# mean  0.46037596464157104
# ----------------------------- 60
# sigma  0.2076827585697174
# mean  0.468746542930603
# ----------------------------- 70
# sigma  0.10035701841115952
# mean  0.49084651470184326
# -------- final sigma,  0.09199512749910355
# -------- final mean  0.49032264947891235
# -------- total number of iterations,  72 -------- average time per iteration (s),  0.0171
# --------- N :  100000
# ----------------------------- 10
# sigma  1.064029335975647
# mean  0.4090934991836548
# ----------------------------- 20
# sigma  0.9191232919692993
# mean  0.4223092198371887
# ----------------------------- 30
# sigma  0.6966484189033508
# mean  0.4076717793941498
# ----------------------------- 40
# sigma  0.4818253517150879
# mean  0.3608410358428955
# ----------------------------- 50
# sigma  0.318364679813385
# mean  0.3163369297981262
# ----------------------------- 60
# sigma  0.2025001049041748
# mean  0.3121122121810913
# ----------------------------- 70
# sigma  0.11482594907283783
# mean  0.32406044006347656
# -------- final sigma,  0.09885147958993912
# -------- final mean  0.31998154520988464
# -------- total number of iterations,  73 -------- average time per iteration (s),  0.0179
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0733797550201416
# mean  0.35849201679229736
# ----------------------------- 20
# sigma  0.8709864616394043
# mean  0.3332209289073944
# ----------------------------- 30
# sigma  0.749619722366333
# mean  0.3154773414134979
# ----------------------------- 40
# sigma  0.5119452476501465
# mean  0.3122520446777344
# ----------------------------- 50
# sigma  0.3510129451751709
# mean  0.2956632375717163
# ----------------------------- 60
# sigma  0.2170529067516327
# mean  0.26065561175346375
# ----------------------------- 70
# sigma  0.11131218820810318
# mean  0.2598492503166199
# -------- final sigma,  0.0967707559466362
# -------- final mean  0.25369420647621155
# -------- total number of iterations,  73 -------- average time per iteration (s),  0.0171
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0318500995635986
# mean  0.4364881217479706
# ----------------------------- 20
# sigma  0.8851675987243652
# mean  0.4264315664768219
# ----------------------------- 30
# sigma  0.6876957416534424
# mean  0.38999035954475403
# ----------------------------- 40
# sigma  0.5116584897041321
# mean  0.4245733618736267
# ----------------------------- 50
# sigma  0.3547604978084564
# mean  0.4575384855270386
# ----------------------------- 60
# sigma  0.23157978057861328
# mean  0.4742724597454071
# ----------------------------- 70
# sigma  0.13850730657577515
# mean  0.475544810295105
# -------- final sigma,  0.09840996563434601
# -------- final mean  0.47204798460006714
# -------- total number of iterations,  76 -------- average time per iteration (s),  0.0172
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0816996097564697
# mean  0.4767111539840698
# ----------------------------- 20
# sigma  0.8917665481567383
# mean  0.4222155511379242
# ----------------------------- 30
# sigma  0.7305180430412292
# mean  0.37004268169403076
# ----------------------------- 40
# sigma  0.5642560124397278
# mean  0.3769141137599945
# ----------------------------- 50
# sigma  0.4071713089942932
# mean  0.3582964837551117
# ----------------------------- 60
# sigma  0.25106558203697205
# mean  0.35177817940711975
# ----------------------------- 70
# sigma  0.14570483565330505
# mean  0.361344575881958
# -------- final sigma,  0.09949112683534622
# -------- final mean  0.35831978917121887
# -------- total number of iterations,  76 -------- average time per iteration (s),  0.0174
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0831882953643799
# mean  0.4501504600048065
# ----------------------------- 20
# sigma  1.0036991834640503
# mean  0.4007450044155121
# ----------------------------- 30
# sigma  0.7744547128677368
# mean  0.4545798897743225
# ----------------------------- 40
# sigma  0.6189197301864624
# mean  0.4139527976512909
# ----------------------------- 50
# sigma  0.47576746344566345
# mean  0.3535168170928955
# ----------------------------- 60
# sigma  0.2693004310131073
# mean  0.3721516728401184
# ----------------------------- 70
# sigma  0.1491125375032425
# mean  0.3809163272380829
# -------- final sigma,  0.09787105023860931
# -------- final mean  0.3846571445465088
# -------- total number of iterations,  77 -------- average time per iteration (s),  0.0173
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0358144044876099
# mean  0.4256947338581085
# ----------------------------- 20
# sigma  0.8915655016899109
# mean  0.41931483149528503
# ----------------------------- 30
# sigma  0.701018214225769
# mean  0.4690733850002289
# ----------------------------- 40
# sigma  0.45718351006507874
# mean  0.4434957802295685
# ----------------------------- 50
# sigma  0.2836100161075592
# mean  0.4255569875240326
# ----------------------------- 60
# sigma  0.1257360875606537
# mean  0.42126697301864624
# -------- final sigma,  0.09244122356176376
# -------- final mean  0.42041972279548645
# -------- total number of iterations,  64 -------- average time per iteration (s),  0.0165
# ------------ group:  B
# --------- N :  100000
# ----------------------------- 10
# sigma  1.1067713499069214
# mean  0.44158118963241577
# ----------------------------- 20
# sigma  0.9848710894584656
# mean  0.3512486219406128
# ----------------------------- 30
# sigma  0.7978578805923462
# mean  0.35440707206726074
# ----------------------------- 40
# sigma  0.5178383588790894
# mean  0.3979833126068115
# ----------------------------- 50
# sigma  0.35064271092414856
# mean  0.4071749746799469
# ----------------------------- 60
# sigma  0.2203291654586792
# mean  0.38868674635887146
# ----------------------------- 70
# sigma  0.12906955182552338
# mean  0.3842433989048004
# -------- final sigma,  0.09292455017566681
# -------- final mean  0.38776475191116333
# -------- total number of iterations,  75 -------- average time per iteration (s),  0.0171
# --------- N :  100000
# ----------------------------- 10
# sigma  1.086857557296753
# mean  0.42721378803253174
# ----------------------------- 20
# sigma  1.0247172117233276
# mean  0.48237770795822144
# ----------------------------- 30
# sigma  0.8404819369316101
# mean  0.4539014399051666
# ----------------------------- 40
# sigma  0.6417631506919861
# mean  0.4297209084033966
# ----------------------------- 50
# sigma  0.42695051431655884
# mean  0.4154048562049866
# ----------------------------- 60
# sigma  0.2435646951198578
# mean  0.39795738458633423
# ----------------------------- 70
# sigma  0.13258828222751617
# mean  0.40343397855758667
# -------- final sigma,  0.09148252755403519
# -------- final mean  0.40217825770378113
# -------- total number of iterations,  75 -------- average time per iteration (s),  0.0171
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0776381492614746
# mean  0.5046018362045288
# ----------------------------- 20
# sigma  0.9987896084785461
# mean  0.46764689683914185
# ----------------------------- 30
# sigma  0.7859586477279663
# mean  0.3910602927207947
# ----------------------------- 40
# sigma  0.5293431878089905
# mean  0.3605715036392212
# ----------------------------- 50
# sigma  0.32044726610183716
# mean  0.3535138666629791
# ----------------------------- 60
# sigma  0.20823729038238525
# mean  0.34531891345977783
# ----------------------------- 70
# sigma  0.09225863218307495
# mean  0.3566601574420929
# -------- final sigma,  0.09225863218307495
# -------- final mean  0.3548657298088074
# -------- total number of iterations,  71 -------- average time per iteration (s),  0.0176
# --------- N :  100000
# ----------------------------- 10
# sigma  1.1015985012054443
# mean  0.41862350702285767
# ----------------------------- 20
# sigma  0.9554190635681152
# mean  0.4592045843601227
# ----------------------------- 30
# sigma  0.703258752822876
# mean  0.539232611656189
# ----------------------------- 40
# sigma  0.48313793540000916
# mean  0.5798195004463196
# ----------------------------- 50
# sigma  0.3064180612564087
# mean  0.58800208568573
# ----------------------------- 60
# sigma  0.14959508180618286
# mean  0.5789754390716553
# -------- final sigma,  0.0895722284913063
# -------- final mean  0.5713445544242859
# -------- total number of iterations,  67 -------- average time per iteration (s),  0.0169
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0379372835159302
# mean  0.36325591802597046
# ----------------------------- 20
# sigma  0.9188588261604309
# mean  0.3545635938644409
# ----------------------------- 30
# sigma  0.7195027470588684
# mean  0.3805065155029297
# ----------------------------- 40
# sigma  0.5101073980331421
# mean  0.33959725499153137
# ----------------------------- 50
# sigma  0.3098391890525818
# mean  0.32538092136383057
# ----------------------------- 60
# sigma  0.18457365036010742
# mean  0.29564327001571655
# ----------------------------- 70
# sigma  0.09811196476221085
# mean  0.3030875623226166
# -------- final sigma,  0.09811196476221085
# -------- final mean  0.303483784198761
# -------- total number of iterations,  71 -------- average time per iteration (s),  0.0176
# --------- N :  100000
# ----------------------------- 10
# sigma  0.9933022260665894
# mean  0.4136202931404114
# ----------------------------- 20
# sigma  0.8671852946281433
# mean  0.40680697560310364
# ----------------------------- 30
# sigma  0.7653363347053528
# mean  0.3929046392440796
# ----------------------------- 40
# sigma  0.5408015251159668
# mean  0.35144346952438354
# ----------------------------- 50
# sigma  0.40621447563171387
# mean  0.32242992520332336
# ----------------------------- 60
# sigma  0.2474241554737091
# mean  0.32456788420677185
# ----------------------------- 70
# sigma  0.13482391834259033
# mean  0.3157898783683777
# -------- final sigma,  0.09711994230747223
# -------- final mean  0.3185024857521057
# -------- total number of iterations,  76 -------- average time per iteration (s),  0.0173
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0489251613616943
# mean  0.39630740880966187
# ----------------------------- 20
# sigma  0.8712645769119263
# mean  0.4385652542114258
# ----------------------------- 30
# sigma  0.6631002426147461
# mean  0.4871232509613037
# ----------------------------- 40
# sigma  0.5053375959396362
# mean  0.5502151846885681
# ----------------------------- 50
# sigma  0.33740875124931335
# mean  0.5946670770645142
# ----------------------------- 60
# sigma  0.21343524754047394
# mean  0.5866204500198364
# ----------------------------- 70
# sigma  0.1138167604804039
# mean  0.590468168258667
# -------- final sigma,  0.09433477371931076
# -------- final mean  0.5917510986328125
# -------- total number of iterations,  73 -------- average time per iteration (s),  0.0185
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0373846292495728
# mean  0.4573532044887543
# ----------------------------- 20
# sigma  0.8948458433151245
# mean  0.35245823860168457
# ----------------------------- 30
# sigma  0.7851801514625549
# mean  0.35532668232917786
# ----------------------------- 40
# sigma  0.5251122713088989
# mean  0.31584465503692627
# ----------------------------- 50
# sigma  0.33719947934150696
# mean  0.3195987343788147
# ----------------------------- 60
# sigma  0.18414419889450073
# mean  0.32235050201416016
# -------- final sigma,  0.09228985756635666
# -------- final mean  0.3178141117095947
# -------- total number of iterations,  70 -------- average time per iteration (s),  0.0176
# --------- N :  100000
# ----------------------------- 10
# sigma  1.110802412033081
# mean  0.46896126866340637
# ----------------------------- 20
# sigma  0.9206942319869995
# mean  0.4192694127559662
# ----------------------------- 30
# sigma  0.7553085684776306
# mean  0.44428324699401855
# ----------------------------- 40
# sigma  0.5270100831985474
# mean  0.4127415418624878
# ----------------------------- 50
# sigma  0.3714302182197571
# mean  0.4160924553871155
# ----------------------------- 60
# sigma  0.21462032198905945
# mean  0.41447147727012634
# ----------------------------- 70
# sigma  0.10232271999120712
# mean  0.4176114797592163
# -------- final sigma,  0.09883007407188416
# -------- final mean  0.415861576795578
# -------- total number of iterations,  72 -------- average time per iteration (s),  0.0176
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0094443559646606
# mean  0.44185560941696167
# ----------------------------- 20
# sigma  0.8677026033401489
# mean  0.4320768415927887
# ----------------------------- 30
# sigma  0.750213086605072
# mean  0.45487335324287415
# ----------------------------- 40
# sigma  0.5506342053413391
# mean  0.5143945217132568
# ----------------------------- 50
# sigma  0.36967933177948
# mean  0.5465691089630127
# ----------------------------- 60
# sigma  0.19997955858707428
# mean  0.5483760237693787
# -------- final sigma,  0.0980352908372879
# -------- final mean  0.5500397682189941
# -------- total number of iterations,  69 -------- average time per iteration (s),  0.0171
# --------- N :  100000
# ----------------------------- 10
# sigma  1.051118016242981
# mean  0.4078952372074127
# ----------------------------- 20
# sigma  0.9546167254447937
# mean  0.38878533244132996
# ----------------------------- 30
# sigma  0.7273354530334473
# mean  0.3886217772960663
# ----------------------------- 40
# sigma  0.547487199306488
# mean  0.4167322516441345
# ----------------------------- 50
# sigma  0.38988086581230164
# mean  0.3876871168613434
# ----------------------------- 60
# sigma  0.25104066729545593
# mean  0.37437495589256287
# ----------------------------- 70
# sigma  0.1442120373249054
# mean  0.3735257387161255
# -------- final sigma,  0.09819448739290237
# -------- final mean  0.3786812722682953
# -------- total number of iterations,  77 -------- average time per iteration (s),  0.0173
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0441806316375732
# mean  0.4038054645061493
# ----------------------------- 20
# sigma  0.9022678136825562
# mean  0.39795246720314026
# ----------------------------- 30
# sigma  0.7774836421012878
# mean  0.40098607540130615
# ----------------------------- 40
# sigma  0.5460876822471619
# mean  0.40746620297431946
# ----------------------------- 50
# sigma  0.33657369017601013
# mean  0.3767080307006836
# ----------------------------- 60
# sigma  0.1788124144077301
# mean  0.3585920035839081
# -------- final sigma,  0.09410576522350311
# -------- final mean  0.34291958808898926
# -------- total number of iterations,  70 -------- average time per iteration (s),  0.0171
# --------- N :  100000
# ----------------------------- 10
# sigma  0.9959781765937805
# mean  0.4046734571456909
# ----------------------------- 20
# sigma  0.9019942283630371
# mean  0.39594927430152893
# ----------------------------- 30
# sigma  0.6487938761711121
# mean  0.42529940605163574
# ----------------------------- 40
# sigma  0.5006779432296753
# mean  0.38653138279914856
# ----------------------------- 50
# sigma  0.324935644865036
# mean  0.37288886308670044
# ----------------------------- 60
# sigma  0.20267994701862335
# mean  0.36941251158714294
# ----------------------------- 70
# sigma  0.1111237034201622
# mean  0.3570917546749115
# -------- final sigma,  0.09910405427217484
# -------- final mean  0.35489821434020996
# -------- total number of iterations,  73 -------- average time per iteration (s),  0.0176
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0849155187606812
# mean  0.4377303719520569
# ----------------------------- 20
# sigma  0.9067947268486023
# mean  0.4728453457355499
# ----------------------------- 30
# sigma  0.7236518263816833
# mean  0.42412129044532776
# ----------------------------- 40
# sigma  0.5068417191505432
# mean  0.4530760645866394
# ----------------------------- 50
# sigma  0.35750776529312134
# mean  0.46338051557540894
# ----------------------------- 60
# sigma  0.21506433188915253
# mean  0.4723156690597534
# ----------------------------- 70
# sigma  0.1028997153043747
# mean  0.4949704706668854
# -------- final sigma,  0.0942702442407608
# -------- final mean  0.49403998255729675
# -------- total number of iterations,  72 -------- average time per iteration (s),  0.0173
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0654864311218262
# mean  0.4100017547607422
# ----------------------------- 20
# sigma  0.9213282465934753
# mean  0.4255770742893219
# ----------------------------- 30
# sigma  0.7003882527351379
# mean  0.41169115900993347
# ----------------------------- 40
# sigma  0.4843966066837311
# mean  0.3643377423286438
# ----------------------------- 50
# sigma  0.31894153356552124
# mean  0.31732475757598877
# ----------------------------- 60
# sigma  0.20331712067127228
# mean  0.30974340438842773
# ----------------------------- 70
# sigma  0.11585503816604614
# mean  0.3228806257247925
# -------- final sigma,  0.09945054352283478
# -------- final mean  0.3194357752799988
# -------- total number of iterations,  73 -------- average time per iteration (s),  0.0172
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0756179094314575
# mean  0.3599202334880829
# ----------------------------- 20
# sigma  0.8754225969314575
# mean  0.33586186170578003
# ----------------------------- 30
# sigma  0.7536391019821167
# mean  0.31751447916030884
# ----------------------------- 40
# sigma  0.5128426551818848
# mean  0.31357499957084656
# ----------------------------- 50
# sigma  0.3541521430015564
# mean  0.29493632912635803
# ----------------------------- 60
# sigma  0.21657291054725647
# mean  0.25652220845222473
# ----------------------------- 70
# sigma  0.11011608690023422
# mean  0.25713521242141724
# -------- final sigma,  0.09576694667339325
# -------- final mean  0.2506018579006195
# -------- total number of iterations,  73 -------- average time per iteration (s),  0.0169
# --------- N :  100000
# ----------------------------- 10
# sigma  1.035081386566162
# mean  0.43715718388557434
# ----------------------------- 20
# sigma  0.890239417552948
# mean  0.4271250069141388
# ----------------------------- 30
# sigma  0.6945871710777283
# mean  0.3896232843399048
# ----------------------------- 40
# sigma  0.5183666944503784
# mean  0.4248165190219879
# ----------------------------- 50
# sigma  0.3602277636528015
# mean  0.4577128291130066
# ----------------------------- 60
# sigma  0.23830397427082062
# mean  0.47313156723976135
# ----------------------------- 70
# sigma  0.1449880450963974
# mean  0.47021543979644775
# -------- final sigma,  0.09611426293849945
# -------- final mean  0.4677792489528656
# -------- total number of iterations,  77 -------- average time per iteration (s),  0.0175
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0837270021438599
# mean  0.47895553708076477
# ----------------------------- 20
# sigma  0.8946788907051086
# mean  0.4233952462673187
# ----------------------------- 30
# sigma  0.7351969480514526
# mean  0.36995401978492737
# ----------------------------- 40
# sigma  0.5699143409729004
# mean  0.3772536516189575
# ----------------------------- 50
# sigma  0.41532111167907715
# mean  0.3533744513988495
# ----------------------------- 60
# sigma  0.2580081820487976
# mean  0.3442492187023163
# ----------------------------- 70
# sigma  0.15331479907035828
# mean  0.35568007826805115
# -------- final sigma,  0.09580975025892258
# -------- final mean  0.35112813115119934
# -------- total number of iterations,  77 -------- average time per iteration (s),  0.0177
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0851930379867554
# mean  0.4516153335571289
# ----------------------------- 20
# sigma  1.007201910018921
# mean  0.40363743901252747
# ----------------------------- 30
# sigma  0.7785822153091431
# mean  0.4587637186050415
# ----------------------------- 40
# sigma  0.6238449811935425
# mean  0.4163578152656555
# ----------------------------- 50
# sigma  0.48142775893211365
# mean  0.35553473234176636
# ----------------------------- 60
# sigma  0.27603307366371155
# mean  0.3740999698638916
# ----------------------------- 70
# sigma  0.1555347740650177
# mean  0.38151076436042786
# -------- final sigma,  0.09614383429288864
# -------- final mean  0.3863218426704407
# -------- total number of iterations,  78 -------- average time per iteration (s),  0.018
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0372145175933838
# mean  0.4267376661300659
# ----------------------------- 20
# sigma  0.8941348195075989
# mean  0.42274996638298035
# ----------------------------- 30
# sigma  0.7030644416809082
# mean  0.47176265716552734
# ----------------------------- 40
# sigma  0.46028199791908264
# mean  0.44456416368484497
# ----------------------------- 50
# sigma  0.29443469643592834
# mean  0.4251236021518707
# ----------------------------- 60
# sigma  0.13564659655094147
# mean  0.42145785689353943
# -------- final sigma,  0.09573599696159363
# -------- final mean  0.4216393530368805
# -------- total number of iterations,  65 -------- average time per iteration (s),  0.0174
# --- 59.1999568939209 seconds ---

# %%
show_im_set(all_samples['A'], n_columns=10 , label='generated by denoiser A')
show_im_set(all_samples['B'], n_columns=10 , label='generated by denoiser B')
