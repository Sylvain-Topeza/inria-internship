# %% [markdown]
# # Generalization
# # UNet with 3 encoder-decoder blocks trained on 80x80 CelebA images

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from skimage.metrics import peak_signal_noise_ratio
import matplotlib.pylab as plt
import matplotlib.colors as colors
import torch
from torch.utils.data import DataLoader

import os
import time                   
import sys
import argparse 

sys.path.insert(0, '../code') 
from network import UNet
from model_loader_func import load_UNet
from plotting_func import plot_many_denoised,  show_im_set, plot_single_im
from quality_metrics_func import calc_psnr, im_set_corr
from linear_approx import calc_jacobian, traj_projections
from inverse_tasks_func import synthesis
from algorithm_inv_prob import univ_inv_sol
from dataloader_func import add_noise_torch

# %matplotlib inline

# %%
print(torch.__version__)
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
device
# Out:
# 1.13.1+cpu
# device(type='cpu')

# %% [markdown]
# ## Load denoisers

# %%
## Load pretraiend denoisers 

denoisers_face = {}
# denoisers in group A are trained on one partision of the data which is non-overlapping with partision B
groups = ['A', 'B'] 
swap = False
training_data_name = 'male_yes-no_40x40'

Ns = [10,100,1000, 10000,84434] #size of the dataset 

for group in groups: 
    print('loading group ' , group )
    denoisers_face[group] = {}
    if group == 'B': 
        swap = True
    for N in Ns:       
        start_time_total = time.time()        
        try: 
            denoisers_face[group][N] = load_UNet(
                           base_path = '../denoisers/UNet',
                           training_data_name= training_data_name, 
                           training_noise='0to255',
                           RF=90,
                           set_size=N, 
                           swap=swap);
        except FileNotFoundError: 
            pass 
        print("--- %s seconds ---" % (round(time.time() - start_time_total)))
# Out:
# loading group  A
# --- 0 seconds ---
# --- 0 seconds ---
# --- 0 seconds ---
# --- 0 seconds ---
# --- 0 seconds ---
# loading group  B
# --- 0 seconds ---
# --- 0 seconds ---
# --- 0 seconds ---
# --- 0 seconds ---
# --- 0 seconds ---

# %%
denoisers_face['A'].keys()
# Out:
# dict_keys([10, 100, 1000, 10000, 84434])

# %% [markdown]
# ## Load datasets

# %%
###### Before running this cell, down the dataset from ??? into the datasets/img_align_celeba/ folder.
###### Dataset consist of CelebA images cropped to 160x160 and then downsampled to 80x80.
###### The RGB channels have been averaged to create grayscale images 

train_face ={}
test_face = {}
train_face['A'] = {}
train_face['B'] ={}
test_face['B'] = {}
test_face['A'] = {}

Ns = [10,100,1000, 10000,84434]

data = torch.load('../datasets/male_yes-no_40x40.pt')
K = data.shape[2] 
print(data.shape)
for N in Ns:
    train_face['A'][N] = data[0:N]
    test_face['A'][N] = data[-N::]
    train_face['B'][N] = data[-N::]
    test_face['B'][N] = data[0:N]
# Out:
# torch.Size([168868, 1, 40, 40])

# %%
## rename N=84434 with N=100000 for ease of use later 
## Do not run this cell twice! 

denoisers_face['A'][100000] = denoisers_face['A'][84434]
del denoisers_face['A'][84434]   
denoisers_face['B'][100000] = denoisers_face['B'][84434]
del denoisers_face['B'][84434]  

train_face['A'][100000] = train_face['A'][84434]
del train_face['A'][84434]   
train_face['B'][100000] = train_face['B'][84434]
del train_face['B'][84434]  

test_face['A'][100000] = test_face['A'][84434]
del test_face['A'][84434]   
test_face['B'][100000] = test_face['B'][84434]
del test_face['B'][84434] 

Ns = list(denoisers_face['A'].keys())
print(Ns)
# Out:
# [10, 100, 1000, 10000, 100000]

# %%
show_im_set(train_face['A'][10][0:10], n_columns=10, label='example training images')

# %%
show_im_set(train_face['B'][10][0:10], n_columns=10, label='example training images')

# %% [markdown]
# # One shot denoising

# %%
## compute psnr on test and train sets as a function of train set size N
sig_range = torch.logspace(.3,2.4,15)
psnr_test = {}
psnr_train = {}
for group in groups: 
    psnr_test[group] = {}
    psnr_train[group] = {}
    for N in Ns: 
        ## train 
        data = train_face[group][N]
        if N <300: 
            data = torch.tile(data, dims=(int(300/N) , 1,1,1))
        else: 
            data = data[0:300]        

        loader = DataLoader(dataset=data, batch_size=300, shuffle=False)
        try:
            print(N)
            psnr_train[group][N] = calc_psnr(denoisers_face[group][N],loader,sig_range , device)
        except KeyError: 
            pass

        ## test 
        data = test_face[group][1000][0:300]    
        loader = DataLoader(dataset=data, batch_size=300, shuffle=False)    
        try: 
            psnr_test[group][N] = calc_psnr(denoisers_face[group][N],loader,sig_range, device)
        except KeyError: 
            pass
# Out:
# 10
# 100
# 1000
# 10000
# 100000
# 10
# 100
# 1000
# 10000
# 100000

# %%
## plot 
group = 'B'
f , axs = plt.subplots(1,2, figsize=(12,7), sharex = True, sharey=True)
plt.tight_layout()
x_axis = [ -10*np.log10( (float(std)/255)**2  ) for std in psnr_train[group][1000].keys()]

for N in [10,100,1000,10000, 100000]: 
    print(N)
    ## train 
    axs[0].plot(x_axis, [psnr_train[group][N][key] for key in psnr_train[group][N].keys()], 
                marker = '.',markersize = 10, alpha = 1,label = 'N: '+ str(N))

    ## test 
    axs[1].plot(x_axis, [psnr_test[group][N][key] for key in psnr_test[group][N].keys()], 
                marker = '.',markersize = 10,label = 'N: '+ str(N), alpha = 1)
for i in range(2):
    axs[i].set_xticks(x_axis);
    axs[i].set_xticklabels(np.round(x_axis).astype(int) ,rotation=90, fontsize=15)
    axs[i].set_xlim(-3, 45)
    
    axs[i].set_yticks(range(9,65,3) );    
    axs[i].set_yticklabels(range(9,65,3), fontsize=15);
    axs[i].set_ylim(9, 65)
    
    axs[i].grid(  linewidth=1);
    
    colormap = plt.cm.copper #nipy_spectral, Set1,Paired   
    plot_colors = [colormap(i) for i in np.linspace(0, 1,len(Ns)+1)]
    for k,j in enumerate(axs[i].lines):
        j.set_color(plot_colors[k])
axs[0].plot(x_axis, [ -10*np.log10( (std/255)**2  ) for std in sig_range/K ],linestyle = 'dotted', color='black')
axs[0].plot( [0,65],[0,65] ,'k--', alpha = .7, label = 'identity');
axs[1].plot( [0,65],[0,65] ,'k--', alpha = .7, label = 'identity');

axs[1].legend(fontsize = 15);
axs[0].set_title('Train', fontsize = 30)
axs[1].set_title('Test', fontsize = 30)
axs[0].set_xlabel('Input PSNR', fontsize = 15)
axs[0].set_ylabel('Output PSNR', fontsize = 15);
axs[1].set_xlabel('Input PSNR', fontsize = 15);
# Out:
# 10
# 100
# 1000
# 10000
# 100000

# %% [markdown]
# # denoise the same image once as the train image and once as the test image

# %%
### pick N 
N = 100000

# %%
### denoise the same test image with different levels of noise using denoisers in the same group 

all_train_A_denoised = {}
all_noisy = {}

n = 0 # im number (must be smaller than N)
im = test_face['A'][N][n:n+1]

sigmas = torch.tensor([0,10,50,150, 255])
with torch.no_grad():
    for s in sigmas:
        s = np.round(s.item())
        noisy , _ = add_noise_torch( im , s )
        all_noisy[s] = noisy
        denoised_im = noisy.to(device) - denoisers_face['A'][N](noisy.to(device)).detach()
        
        all_train_A_denoised[np.round(s/255, 3)] = denoised_im
        if N ==1:
            print('expected distance: ', str(s/255/80 ))
### plot
plot_many_denoised(im, all_noisy, all_train_A_denoised ,device, 
                   suptitle = 'same denoiser, diff noise levels ', 
                   label='sigma : ', train= False, vmin=0, vmax=1, im_size=3)
# Out:
# c:\Users\sylva\Documents\Python\Inria\.inria\lib\site-packages\skimage\metrics\simple_metrics.py:163: RuntimeWarning: divide by zero encountered in scalar divide
#   return 10 * np.log10((data_range ** 2) / err)

# %%
### Now the same image is a train image for denoisers in group B
### Performance on the same image when it is a train image 
all_train_A_denoised = {}
all_noisy = {}


sigmas = torch.tensor([0,10,50,150, 255])
with torch.no_grad():
    for s in sigmas:
        s = np.round(s.item())
        noisy , _ = add_noise_torch( im , s )
        all_noisy[s] = noisy
        denoised_im = noisy.to(device)-denoisers_face['B'][N](noisy.to(device)).detach()
        
        all_train_A_denoised[np.round(s/255, 3)] = denoised_im
        if N ==1:
            print('expected distance: ', str(s/255/80 ))
### plot
plot_many_denoised(im, all_noisy, all_train_A_denoised ,device, 
                   suptitle = 'same denoiser, diff noise levels ', 
                   label='sigma : ', train= True, vmin=0, vmax=1, im_size=3)

# %% [markdown]
# # Synthesis

# %% [markdown]
# # Compare samples from two sets of denoisers

# %%
# generate samples starting from all_interm_Ysme seed using both denoisers 
                                                                                                        
synth = synthesis() 
samples_faces = {}
all_interm_Ys = {}
seed = 0
for group in groups: 
    samples_faces[group] = {}
    all_interm_Ys[group] = {}
    for N in Ns: 
        torch.manual_seed(seed)
        sample, interm_Ys,all_sigs, all_means =univ_inv_sol(denoisers_face[group][N], 
                                                             x_c= torch.zeros(1,K,K),
                                                             task=synth,
                                                             device=device,
                                                             sig_0=1, 
                                                             sig_L=.1, 
                                                             h0=.01 , 
                                                             beta=.1 , 
                                                             freq=0,
                                                             seed = seed, 
                                                             init_im = train_face[group][N].mean(dim=0)+ torch.randn(1,K,K, device = device), 
                                                             init_noise_mean=0,
                                                             max_T=2000, 
                                                             fixed_h=False)

        samples_faces[group][N] = sample.detach()
        all_interm_Ys[group][N] = interm_Ys
# Out:
# -------- final sigma,  0.09992288053035736
# -------- final mean  0.3789128065109253
# -------- total number of iterations,  87 -------- average time per iteration (s),  0.0282
# -------- final sigma,  0.0936909019947052
# -------- final mean  0.37777748703956604
# -------- total number of iterations,  88 -------- average time per iteration (s),  0.0258
# -------- final sigma,  0.09834055602550507
# -------- final mean  0.31255075335502625
# -------- total number of iterations,  87 -------- average time per iteration (s),  0.0273
# -------- final sigma,  0.09753337502479553
# -------- final mean  0.3834724724292755
# -------- total number of iterations,  79 -------- average time per iteration (s),  0.0258
# -------- final sigma,  0.09623776376247406
# -------- final mean  0.37173157930374146
# -------- total number of iterations,  73 -------- average time per iteration (s),  0.0264
# -------- final sigma,  0.09384172409772873
# -------- final mean  0.3486623466014862
# -------- total number of iterations,  88 -------- average time per iteration (s),  0.0262
# -------- final sigma,  0.09980706870555878
# -------- final mean  0.43762490153312683
# -------- total number of iterations,  87 -------- average time per iteration (s),  0.0257
# -------- final sigma,  0.09480664134025574
# -------- final mean  0.3990269899368286
# -------- total number of iterations,  87 -------- average time per iteration (s),  0.0252
# -------- final sigma,  0.09616503864526749
# -------- final mean  0.40407729148864746
# -------- total number of iterations,  77 -------- average time per iteration (s),  0.0259
# -------- final sigma,  0.09606293588876724
# -------- final mean  0.4004647135734558
# -------- total number of iterations,  76 -------- average time per iteration (s),  0.026

# %%
group = 'A'
show_im_set(torch.stack([v for k, v in samples_faces[group].items()]), label='',sub_labels= ['N='+str(N) for N in denoisers_face[group].keys()] , n_columns=5)
group = 'B'
show_im_set(torch.stack([v for k, v in samples_faces[group].items()]), label='',sub_labels= ['']*5 , n_columns=5)

# %%
closest_train = {}
for group in groups: 
    closest_train[group] = []
    for N in Ns:
        corrs = im_set_corr(samples_faces[group][N].unsqueeze(0).to(device), 
                            train_face[group][N].to(device), remove_mean=True)
        values, indices = corrs.max(dim = 1)
        closest_train[group].append(train_face[group][N][indices.cpu()])

# %%
plt.figure()
group = 'A'
show_im_set(torch.vstack(closest_train[group]), label='',sub_labels= ['N='+str(N) for N in denoisers_face[group].keys()] , n_columns=5)
show_im_set(torch.stack([v for k, v in samples_faces[group].items()]), label='',sub_labels= ['']*5, n_columns=5)

group = 'B'
show_im_set(torch.stack([v for k, v in samples_faces[group].items()]), label='',sub_labels= ['']*5 , n_columns=5)
show_im_set(torch.vstack(closest_train[group]), label='',sub_labels= ['']*5 , n_columns=5);

# %%
more_closest_train = {}
for group in groups: 
    more_closest_train[group] = [[] for _ in range(10)]
    for i in range(10):
        more_closest_train[group][i] = []
        for N in Ns:
            corrs = im_set_corr(samples_faces[group][N].unsqueeze(0).to(device), 
                            train_face[group][N].to(device), remove_mean=True)
            values, indices = corrs.topk(10, dim = 1)
            closest_img = train_face[group][N][indices[0, i].cpu()]
            value = values[0, i].cpu().item()
            more_closest_train[group][i].append((closest_img, value))

# %%
plt.figure()
group = 'A'
for i in reversed(range(10)):
    images = [item[0] for item in more_closest_train[group][i]]
    corrs = [f"{item[1]:.3f}" for item in more_closest_train[group][i]]
    show_im_set(torch.stack(images), label="'"*(i+1),sub_labels= corrs, n_columns=5)
show_im_set(torch.stack([v for k, v in samples_faces[group].items()]), label='samples from group A',sub_labels= ['']*5, n_columns=5)

group = 'B'
show_im_set(torch.stack([v for k, v in samples_faces[group].items()]), label='samples from group B',sub_labels= ['']*5 , n_columns=5)
for i in range(10):
    images = [item[0] for item in more_closest_train[group][i]]
    corrs = [f"{item[1]:.3f}" for item in more_closest_train[group][i]]
    show_im_set(torch.stack(images), label="'"*(i+1),sub_labels= corrs , n_columns=5)
# Out:
# c:\Users\sylva\Documents\Python\Inria\xp\notebooks\../code\plotting_func.py:427: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   f, axs = plt.subplots(n_rows, n_columns, figsize = (im_size * n_columns , im_size * n_rows))

# %%
from tqdm import tqdm
import lpips
loss_fn_alex = lpips.LPIPS(net='alex')
loss_fn_vgg = lpips.LPIPS(net='vgg')

def prep_for_lpips(img): # img: [1, H, W] in [0, 1] → returns [3, H, W] in [-1, 1]
    if img.max() > 1.1:
        img = img / 255.0
    img_rgb = img.expand(3, -1, -1)
    return img_rgb * 2 - 1
# Out:
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# c:\Users\sylva\Documents\Python\Inria\.inria\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\sylva\Documents\Python\Inria\.inria\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: c:\Users\sylva\Documents\Python\Inria\.inria\lib\site-packages\lpips\weights\v0.1\alex.pth
# Setting up [LPIPS] perceptual loss: trunk [vgg], v[0.1], spatial [off]
# c:\Users\sylva\Documents\Python\Inria\.inria\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: c:\Users\sylva\Documents\Python\Inria\.inria\lib\site-packages\lpips\weights\v0.1\vgg.pth

# %%
lpips_closest_train = {}
for group in groups: 
    lpips_closest_train[group] = [[] for _ in range(10)]
    for i in range(10):
        lpips_closest_train[group][i] = []
        for N in Ns:
            corrs = im_set_corr(samples_faces[group][N].unsqueeze(0).to(device), 
                            train_face[group][N].to(device), remove_mean=True)
            values, indices = corrs.topk(10, dim = 1)
            closest_img = train_face[group][N][indices[0, i].cpu()]
            value = values[0, i].cpu().item()
            lpips_closest_train[group][i].append((closest_img, value))

# %%
plt.figure()
group = 'A'

for i in reversed(range(10)):
    images = [item[0] for item in lpips_closest_train[group][i]]
    corrs = [f"{item[1]:.3f}" for item in lpips_closest_train[group][i]]

    samples = [samples_faces[group][N] for N in Ns]

    lpips_scores = []
    for gen_img, close_img in zip(samples, images):
        gen_ref   = prep_for_lpips(gen_img.cpu())
        close_rgb = prep_for_lpips(close_img.cpu())
        val = loss_fn_vgg(gen_ref.unsqueeze(0).to(device), close_rgb.unsqueeze(0).to(device))
        lpips_scores.append(f"{val.item():.3f}")

    show_im_set(torch.stack(images), label="'"*(i+1),sub_labels=[f"corr={c}\nlpips={l}" for c, l in zip(corrs, lpips_scores)], n_columns=5)

show_im_set(torch.stack([v for k, v in samples_faces[group].items()]), label='samples from group A',sub_labels= ['']*5, n_columns=5)

group = 'B'

show_im_set(torch.stack([v for k, v in samples_faces[group].items()]), label='samples from group B',sub_labels= ['']*5 , n_columns=5)

for i in range(10):
    images = [item[0] for item in lpips_closest_train[group][i]]
    corrs = [f"{item[1]:.3f}" for item in lpips_closest_train[group][i]]

    samples = [samples_faces[group][N] for N in Ns]

    lpips_scores = []
    for gen_img, close_img in zip(samples, images):
        gen_ref   = prep_for_lpips(gen_img.cpu())
        close_rgb = prep_for_lpips(close_img.cpu())
        val = loss_fn_vgg(gen_ref.unsqueeze(0).to(device), close_rgb.unsqueeze(0).to(device))
        lpips_scores.append(f"{val.item():.3f}")

    show_im_set(torch.stack(images), label="'"*(i+1),sub_labels = [f"corr={c}\nlpips={l}" for c, l in zip(corrs, lpips_scores)], n_columns=5)
# Out:
# c:\Users\sylva\Documents\Python\Inria\xp\notebooks\../code\plotting_func.py:427: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   f, axs = plt.subplots(n_rows, n_columns, figsize = (im_size * n_columns , im_size * n_rows))

# %%
#Generate many samples from a pair of denoisers trained on N images 
N = 100000
n_samples = 20
shift = 0
seeds = range(shift,shift+n_samples)
freq =10

all_samples = {}
all_interm_Ys = {}
all_sigmas={}
all_means = {}

start_time_total = time.time()
synth = synthesis()

for group in groups: 
    print('------------ group: ', group)
  
    all_samples[group] = torch.zeros(n_samples, 1, K,K).to(device)
    all_interm_Ys[group] = []
    all_sigmas[group] = []
    all_means[group] = [] 
    
    for n in range(n_samples): 
        print('--------- N : ', N)        
        torch.manual_seed(seeds[n])
        sample, interm_Ys,sigmas, means =univ_inv_sol(denoisers_face[group][N], 
                                                             x_c= torch.zeros(1,K,K),
                                                             task=synth,
                                                             device=device,
                                                             sig_0=1, 
                                                             sig_L=.1, 
                                                             h0=.01 , 
                                                             beta=.1 , 
                                                             freq=freq,
                                                             seed = seeds[n], 
                                                             init_im = train_face[group][N].mean(dim=0) + torch.randn(1,K,K, device = device), 
                                                             init_noise_mean=0,
                                                             max_T=10000, 
                                                             fixed_h=False)
        all_samples[group][n, 0] = sample.detach()
        all_interm_Ys[group].append(interm_Ys)
        all_sigmas[group].append(sigmas)
        all_means[group].append(means)
        
print("--- %s seconds ---" % (time.time() - start_time_total))
# Out:
# ------------ group:  A
# --------- N :  100000
# ----------------------------- 10
# sigma  1.1091667413711548
# mean  0.4362100660800934
# ----------------------------- 20
# sigma  0.9863077402114868
# mean  0.34397652745246887
# ----------------------------- 30
# sigma  0.7982844114303589
# mean  0.3451792597770691
# ----------------------------- 40
# sigma  0.5220280885696411
# mean  0.3865194320678711
# ----------------------------- 50
# sigma  0.3548949956893921
# mean  0.39566364884376526
# ----------------------------- 60
# sigma  0.2165997326374054
# mean  0.37623515725135803
# ----------------------------- 70
# sigma  0.1177515760064125
# mean  0.371359258890152
# -------- final sigma,  0.09623776376247406
# -------- final mean  0.37173157930374146
# -------- total number of iterations,  73 -------- average time per iteration (s),  0.0234
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0871660709381104
# mean  0.4221695065498352
# ----------------------------- 20
# sigma  1.0264708995819092
# mean  0.4729405641555786
# ----------------------------- 30
# sigma  0.8431085348129272
# mean  0.4457939565181732
# ----------------------------- 40
# sigma  0.6444748044013977
# mean  0.4263623356819153
# ----------------------------- 50
# sigma  0.42297491431236267
# mean  0.4172879159450531
# ----------------------------- 60
# sigma  0.24717101454734802
# mean  0.40907761454582214
# ----------------------------- 70
# sigma  0.14342841506004333
# mean  0.42161816358566284
# -------- final sigma,  0.09453441202640533
# -------- final mean  0.42254438996315
# -------- total number of iterations,  76 -------- average time per iteration (s),  0.0219
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0785458087921143
# mean  0.4995679557323456
# ----------------------------- 20
# sigma  0.9984874725341797
# mean  0.46043118834495544
# ----------------------------- 30
# sigma  0.7834978103637695
# mean  0.3828359842300415
# ----------------------------- 40
# sigma  0.5159410238265991
# mean  0.35293400287628174
# ----------------------------- 50
# sigma  0.2893178164958954
# mean  0.34759005904197693
# ----------------------------- 60
# sigma  0.1684393435716629
# mean  0.3372197449207306
# -------- final sigma,  0.09502618759870529
# -------- final mean  0.341048002243042
# -------- total number of iterations,  67 -------- average time per iteration (s),  0.0215
# --------- N :  100000
# ----------------------------- 10
# sigma  1.1025935411453247
# mean  0.4115704298019409
# ----------------------------- 20
# sigma  0.957636833190918
# mean  0.44738808274269104
# ----------------------------- 30
# sigma  0.7065727114677429
# mean  0.5238739252090454
# ----------------------------- 40
# sigma  0.479879766702652
# mean  0.5657777190208435
# ----------------------------- 50
# sigma  0.2950650751590729
# mean  0.5757095217704773
# ----------------------------- 60
# sigma  0.14709332585334778
# mean  0.5625672340393066
# -------- final sigma,  0.09798915684223175
# -------- final mean  0.5541610717773438
# -------- total number of iterations,  66 -------- average time per iteration (s),  0.0219
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0377672910690308
# mean  0.3575919270515442
# ----------------------------- 20
# sigma  0.9191586375236511
# mean  0.3463325798511505
# ----------------------------- 30
# sigma  0.7195185422897339
# mean  0.368436723947525
# ----------------------------- 40
# sigma  0.5083872675895691
# mean  0.32412269711494446
# ----------------------------- 50
# sigma  0.308631956577301
# mean  0.30975210666656494
# ----------------------------- 60
# sigma  0.1800713837146759
# mean  0.27380985021591187
# -------- final sigma,  0.09964416921138763
# -------- final mean  0.27806586027145386
# -------- total number of iterations,  70 -------- average time per iteration (s),  0.0216
# --------- N :  100000
# ----------------------------- 10
# sigma  0.9949673414230347
# mean  0.40790241956710815
# ----------------------------- 20
# sigma  0.8666361570358276
# mean  0.3983411490917206
# ----------------------------- 30
# sigma  0.7658926248550415
# mean  0.38191670179367065
# ----------------------------- 40
# sigma  0.5419520735740662
# mean  0.33898627758026123
# ----------------------------- 50
# sigma  0.40921449661254883
# mean  0.3040163516998291
# ----------------------------- 60
# sigma  0.25090935826301575
# mean  0.30778267979621887
# ----------------------------- 70
# sigma  0.13781356811523438
# mean  0.29913920164108276
# -------- final sigma,  0.09929502755403519
# -------- final mean  0.3016744554042816
# -------- total number of iterations,  76 -------- average time per iteration (s),  0.0217
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0500452518463135
# mean  0.39041343331336975
# ----------------------------- 20
# sigma  0.8739005923271179
# mean  0.4330979287624359
# ----------------------------- 30
# sigma  0.6669152975082397
# mean  0.48427730798721313
# ----------------------------- 40
# sigma  0.5059166550636292
# mean  0.550774097442627
# ----------------------------- 50
# sigma  0.3358648121356964
# mean  0.5930676460266113
# ----------------------------- 60
# sigma  0.21292027831077576
# mean  0.5839898586273193
# ----------------------------- 70
# sigma  0.11477658897638321
# mean  0.5886169672012329
# -------- final sigma,  0.09481240063905716
# -------- final mean  0.5899348855018616
# -------- total number of iterations,  73 -------- average time per iteration (s),  0.0217
# --------- N :  100000
# ----------------------------- 10
# sigma  1.040003776550293
# mean  0.45105239748954773
# ----------------------------- 20
# sigma  0.8974586725234985
# mean  0.34628087282180786
# ----------------------------- 30
# sigma  0.7822364568710327
# mean  0.34914034605026245
# ----------------------------- 40
# sigma  0.5253043174743652
# mean  0.3085666000843048
# ----------------------------- 50
# sigma  0.3398802876472473
# mean  0.3132803440093994
# ----------------------------- 60
# sigma  0.19211933016777039
# mean  0.3129420578479767
# -------- final sigma,  0.09770894050598145
# -------- final mean  0.3084181249141693
# -------- total number of iterations,  70 -------- average time per iteration (s),  0.0216
# --------- N :  100000
# ----------------------------- 10
# sigma  1.1103616952896118
# mean  0.46026381850242615
# ----------------------------- 20
# sigma  0.9177075624465942
# mean  0.4060746133327484
# ----------------------------- 30
# sigma  0.7553589344024658
# mean  0.4309636950492859
# ----------------------------- 40
# sigma  0.5299350023269653
# mean  0.3995397090911865
# ----------------------------- 50
# sigma  0.375235378742218
# mean  0.40295636653900146
# ----------------------------- 60
# sigma  0.22024767100811005
# mean  0.39917922019958496
# ----------------------------- 70
# sigma  0.10990186035633087
# mean  0.40297621488571167
# -------- final sigma,  0.09784615784883499
# -------- final mean  0.4041605293750763
# -------- total number of iterations,  73 -------- average time per iteration (s),  0.0226
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0089865922927856
# mean  0.4368290305137634
# ----------------------------- 20
# sigma  0.8682689666748047
# mean  0.423787921667099
# ----------------------------- 30
# sigma  0.753090500831604
# mean  0.44517791271209717
# ----------------------------- 40
# sigma  0.5551839470863342
# mean  0.5059786438941956
# ----------------------------- 50
# sigma  0.37206465005874634
# mean  0.5397886037826538
# ----------------------------- 60
# sigma  0.20143604278564453
# mean  0.5417374968528748
# -------- final sigma,  0.09453990310430527
# -------- final mean  0.543710470199585
# -------- total number of iterations,  69 -------- average time per iteration (s),  0.0224
# --------- N :  100000
# ----------------------------- 10
# sigma  1.051710605621338
# mean  0.4025534689426422
# ----------------------------- 20
# sigma  0.9554069638252258
# mean  0.38426122069358826
# ----------------------------- 30
# sigma  0.7286604046821594
# mean  0.3872438669204712
# ----------------------------- 40
# sigma  0.5495700836181641
# mean  0.413074791431427
# ----------------------------- 50
# sigma  0.39331215620040894
# mean  0.38221293687820435
# ----------------------------- 60
# sigma  0.2558908462524414
# mean  0.3631899654865265
# ----------------------------- 70
# sigma  0.14665205776691437
# mean  0.3609876334667206
# -------- final sigma,  0.09216417372226715
# -------- final mean  0.3637206256389618
# -------- total number of iterations,  78 -------- average time per iteration (s),  0.0222
# --------- N :  100000
# ----------------------------- 10
# sigma  1.046311616897583
# mean  0.3975282311439514
# ----------------------------- 20
# sigma  0.9043753743171692
# mean  0.389047235250473
# ----------------------------- 30
# sigma  0.7808588743209839
# mean  0.3870397210121155
# ----------------------------- 40
# sigma  0.5506172776222229
# mean  0.38991379737854004
# ----------------------------- 50
# sigma  0.3409155309200287
# mean  0.3535199761390686
# ----------------------------- 60
# sigma  0.18419834971427917
# mean  0.3323823809623718
# -------- final sigma,  0.09665475785732269
# -------- final mean  0.31507325172424316
# -------- total number of iterations,  70 -------- average time per iteration (s),  0.0213
# --------- N :  100000
# ----------------------------- 10
# sigma  0.9947003126144409
# mean  0.3966134786605835
# ----------------------------- 20
# sigma  0.9023057222366333
# mean  0.3829968273639679
# ----------------------------- 30
# sigma  0.6458825469017029
# mean  0.40713515877723694
# ----------------------------- 40
# sigma  0.49855613708496094
# mean  0.3658444881439209
# ----------------------------- 50
# sigma  0.3235560655593872
# mean  0.34596890211105347
# ----------------------------- 60
# sigma  0.20859317481517792
# mean  0.340860515832901
# ----------------------------- 70
# sigma  0.11891919374465942
# mean  0.3260173499584198
# -------- final sigma,  0.09843488037586212
# -------- final mean  0.32463404536247253
# -------- total number of iterations,  74 -------- average time per iteration (s),  0.0215
# --------- N :  100000
# ----------------------------- 10
# sigma  1.088003396987915
# mean  0.43173232674598694
# ----------------------------- 20
# sigma  0.9104043841362
# mean  0.4633902609348297
# ----------------------------- 30
# sigma  0.723996639251709
# mean  0.41018417477607727
# ----------------------------- 40
# sigma  0.5046781897544861
# mean  0.43823379278182983
# ----------------------------- 50
# sigma  0.35795900225639343
# mean  0.44581735134124756
# ----------------------------- 60
# sigma  0.21450094878673553
# mean  0.4521593451499939
# ----------------------------- 70
# sigma  0.11202318966388702
# mean  0.47438889741897583
# -------- final sigma,  0.09795393794775009
# -------- final mean  0.4739583730697632
# -------- total number of iterations,  73 -------- average time per iteration (s),  0.0222
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0664646625518799
# mean  0.403310090303421
# ----------------------------- 20
# sigma  0.9254509806632996
# mean  0.4135495126247406
# ----------------------------- 30
# sigma  0.7030821442604065
# mean  0.395423024892807
# ----------------------------- 40
# sigma  0.4878452718257904
# mean  0.3455144464969635
# ----------------------------- 50
# sigma  0.32255440950393677
# mean  0.29999226331710815
# ----------------------------- 60
# sigma  0.20645353198051453
# mean  0.294711709022522
# ----------------------------- 70
# sigma  0.11878303438425064
# mean  0.30516472458839417
# -------- final sigma,  0.09538019448518753
# -------- final mean  0.30157849192619324
# -------- total number of iterations,  74 -------- average time per iteration (s),  0.0217
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0770364999771118
# mean  0.35454386472702026
# ----------------------------- 20
# sigma  0.8773161172866821
# mean  0.33209654688835144
# ----------------------------- 30
# sigma  0.7530430555343628
# mean  0.3122570514678955
# ----------------------------- 40
# sigma  0.5096079111099243
# mean  0.3111681640148163
# ----------------------------- 50
# sigma  0.3499653935432434
# mean  0.29532498121261597
# ----------------------------- 60
# sigma  0.21583807468414307
# mean  0.25656259059906006
# ----------------------------- 70
# sigma  0.11191505193710327
# mean  0.2532845437526703
# -------- final sigma,  0.09826172888278961
# -------- final mean  0.2461707442998886
# -------- total number of iterations,  73 -------- average time per iteration (s),  0.0212
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0362008810043335
# mean  0.4318624436855316
# ----------------------------- 20
# sigma  0.8909354209899902
# mean  0.4216678738594055
# ----------------------------- 30
# sigma  0.6939601302146912
# mean  0.37887755036354065
# ----------------------------- 40
# sigma  0.5176594257354736
# mean  0.40966200828552246
# ----------------------------- 50
# sigma  0.3620527386665344
# mean  0.4427889585494995
# ----------------------------- 60
# sigma  0.23980405926704407
# mean  0.45655253529548645
# ----------------------------- 70
# sigma  0.14456883072853088
# mean  0.4566996395587921
# -------- final sigma,  0.09525497257709503
# -------- final mean  0.45443516969680786
# -------- total number of iterations,  77 -------- average time per iteration (s),  0.0215
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0846397876739502
# mean  0.471368670463562
# ----------------------------- 20
# sigma  0.894023597240448
# mean  0.40891629457473755
# ----------------------------- 30
# sigma  0.7358068227767944
# mean  0.3574800193309784
# ----------------------------- 40
# sigma  0.5692671537399292
# mean  0.36254504323005676
# ----------------------------- 50
# sigma  0.4126507639884949
# mean  0.3391381800174713
# ----------------------------- 60
# sigma  0.2610217034816742
# mean  0.32260048389434814
# ----------------------------- 70
# sigma  0.1630076915025711
# mean  0.32996758818626404
# -------- final sigma,  0.09847036004066467
# -------- final mean  0.32265183329582214
# -------- total number of iterations,  78 -------- average time per iteration (s),  0.0223
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0866403579711914
# mean  0.4434049129486084
# ----------------------------- 20
# sigma  1.008857011795044
# mean  0.3925011157989502
# ----------------------------- 30
# sigma  0.782954752445221
# mean  0.44609278440475464
# ----------------------------- 40
# sigma  0.6274328827857971
# mean  0.4033474326133728
# ----------------------------- 50
# sigma  0.4864521026611328
# mean  0.33869221806526184
# ----------------------------- 60
# sigma  0.2785341143608093
# mean  0.3536161780357361
# ----------------------------- 70
# sigma  0.15600493550300598
# mean  0.3585797846317291
# -------- final sigma,  0.09655886888504028
# -------- final mean  0.3614538908004761
# -------- total number of iterations,  78 -------- average time per iteration (s),  0.0214
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0365989208221436
# mean  0.4185168445110321
# ----------------------------- 20
# sigma  0.8937255144119263
# mean  0.40969622135162354
# ----------------------------- 30
# sigma  0.6972097754478455
# mean  0.45931702852249146
# ----------------------------- 40
# sigma  0.45319968461990356
# mean  0.4345138967037201
# ----------------------------- 50
# sigma  0.28522199392318726
# mean  0.4176633358001709
# ----------------------------- 60
# sigma  0.13325482606887817
# mean  0.41591930389404297
# -------- final sigma,  0.09295503050088882
# -------- final mean  0.41471022367477417
# -------- total number of iterations,  65 -------- average time per iteration (s),  0.0215
# ------------ group:  B
# --------- N :  100000
# ----------------------------- 10
# sigma  1.1077306270599365
# mean  0.44483256340026855
# ----------------------------- 20
# sigma  0.9858018159866333
# mean  0.3579500913619995
# ----------------------------- 30
# sigma  0.7975423336029053
# mean  0.3641739785671234
# ----------------------------- 40
# sigma  0.5217245817184448
# mean  0.40500637888908386
# ----------------------------- 50
# sigma  0.3577623963356018
# mean  0.41503846645355225
# ----------------------------- 60
# sigma  0.22629129886627197
# mean  0.39824408292770386
# ----------------------------- 70
# sigma  0.1369057595729828
# mean  0.39715802669525146
# -------- final sigma,  0.09606293588876724
# -------- final mean  0.4004647135734558
# -------- total number of iterations,  76 -------- average time per iteration (s),  0.0209
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0870490074157715
# mean  0.42770907282829285
# ----------------------------- 20
# sigma  1.023338794708252
# mean  0.4804519712924957
# ----------------------------- 30
# sigma  0.8378451466560364
# mean  0.44964486360549927
# ----------------------------- 40
# sigma  0.6384605765342712
# mean  0.42295947670936584
# ----------------------------- 50
# sigma  0.42793431878089905
# mean  0.40855395793914795
# ----------------------------- 60
# sigma  0.24320921301841736
# mean  0.3848031759262085
# ----------------------------- 70
# sigma  0.13357771933078766
# mean  0.38856780529022217
# -------- final sigma,  0.09586331248283386
# -------- final mean  0.3867112100124359
# -------- total number of iterations,  75 -------- average time per iteration (s),  0.0219
# --------- N :  100000
# ----------------------------- 10
# sigma  1.078490138053894
# mean  0.5061484575271606
# ----------------------------- 20
# sigma  1.0005719661712646
# mean  0.46905314922332764
# ----------------------------- 30
# sigma  0.78985595703125
# mean  0.3954918682575226
# ----------------------------- 40
# sigma  0.5416996479034424
# mean  0.3637697696685791
# ----------------------------- 50
# sigma  0.3325285315513611
# mean  0.3556753993034363
# ----------------------------- 60
# sigma  0.21723663806915283
# mean  0.3464372158050537
# ----------------------------- 70
# sigma  0.09933317452669144
# mean  0.3579370081424713
# -------- final sigma,  0.09933317452669144
# -------- final mean  0.3561266362667084
# -------- total number of iterations,  71 -------- average time per iteration (s),  0.0209
# --------- N :  100000
# ----------------------------- 10
# sigma  1.1009433269500732
# mean  0.4201198220252991
# ----------------------------- 20
# sigma  0.9557282328605652
# mean  0.4591825604438782
# ----------------------------- 30
# sigma  0.7046182751655579
# mean  0.5315670967102051
# ----------------------------- 40
# sigma  0.4870281219482422
# mean  0.5664251446723938
# ----------------------------- 50
# sigma  0.3102245330810547
# mean  0.5748547315597534
# ----------------------------- 60
# sigma  0.15676070749759674
# mean  0.563087522983551
# -------- final sigma,  0.09462277591228485
# -------- final mean  0.5557318329811096
# -------- total number of iterations,  67 -------- average time per iteration (s),  0.0214
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0364172458648682
# mean  0.3638615310192108
# ----------------------------- 20
# sigma  0.9184820055961609
# mean  0.3526780307292938
# ----------------------------- 30
# sigma  0.7196544408798218
# mean  0.37964776158332825
# ----------------------------- 40
# sigma  0.5127636194229126
# mean  0.33825284242630005
# ----------------------------- 50
# sigma  0.3116667568683624
# mean  0.32289764285087585
# ----------------------------- 60
# sigma  0.18455633521080017
# mean  0.2921053469181061
# ----------------------------- 70
# sigma  0.09478122740983963
# mean  0.29897040128707886
# -------- final sigma,  0.09478122740983963
# -------- final mean  0.29932931065559387
# -------- total number of iterations,  71 -------- average time per iteration (s),  0.0213
# --------- N :  100000
# ----------------------------- 10
# sigma  0.9936701059341431
# mean  0.4148690402507782
# ----------------------------- 20
# sigma  0.8667686581611633
# mean  0.40791603922843933
# ----------------------------- 30
# sigma  0.7656973004341125
# mean  0.3972252905368805
# ----------------------------- 40
# sigma  0.5410844087600708
# mean  0.35136231780052185
# ----------------------------- 50
# sigma  0.40543025732040405
# mean  0.31810927391052246
# ----------------------------- 60
# sigma  0.2461366206407547
# mean  0.319847971200943
# ----------------------------- 70
# sigma  0.1336994767189026
# mean  0.3097881078720093
# -------- final sigma,  0.09658502042293549
# -------- final mean  0.3126208484172821
# -------- total number of iterations,  76 -------- average time per iteration (s),  0.0215
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0494825839996338
# mean  0.39764758944511414
# ----------------------------- 20
# sigma  0.8747768402099609
# mean  0.44067925214767456
# ----------------------------- 30
# sigma  0.6703637838363647
# mean  0.48661094903945923
# ----------------------------- 40
# sigma  0.51272052526474
# mean  0.5528860092163086
# ----------------------------- 50
# sigma  0.33739903569221497
# mean  0.5979913473129272
# ----------------------------- 60
# sigma  0.21080072224140167
# mean  0.5937923192977905
# ----------------------------- 70
# sigma  0.11073370277881622
# mean  0.6001883745193481
# -------- final sigma,  0.09084194898605347
# -------- final mean  0.6021559238433838
# -------- total number of iterations,  73 -------- average time per iteration (s),  0.0216
# --------- N :  100000
# ----------------------------- 10
# sigma  1.036466121673584
# mean  0.4579891264438629
# ----------------------------- 20
# sigma  0.8958731889724731
# mean  0.3529103100299835
# ----------------------------- 30
# sigma  0.7825649976730347
# mean  0.35711774230003357
# ----------------------------- 40
# sigma  0.5239309668540955
# mean  0.3138626217842102
# ----------------------------- 50
# sigma  0.3359106779098511
# mean  0.3233541250228882
# ----------------------------- 60
# sigma  0.18474623560905457
# mean  0.32881996035575867
# -------- final sigma,  0.094107985496521
# -------- final mean  0.3249312937259674
# -------- total number of iterations,  70 -------- average time per iteration (s),  0.0212
# --------- N :  100000
# ----------------------------- 10
# sigma  1.1088645458221436
# mean  0.4693579375743866
# ----------------------------- 20
# sigma  0.9192268252372742
# mean  0.4198180139064789
# ----------------------------- 30
# sigma  0.7571710348129272
# mean  0.44948628544807434
# ----------------------------- 40
# sigma  0.5254596471786499
# mean  0.4110378324985504
# ----------------------------- 50
# sigma  0.36687642335891724
# mean  0.40435242652893066
# ----------------------------- 60
# sigma  0.2083873450756073
# mean  0.39833953976631165
# ----------------------------- 70
# sigma  0.09620313346385956
# mean  0.39753520488739014
# -------- final sigma,  0.09620313346385956
# -------- final mean  0.3963978886604309
# -------- total number of iterations,  71 -------- average time per iteration (s),  0.0223
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0063254833221436
# mean  0.4426532983779907
# ----------------------------- 20
# sigma  0.864448070526123
# mean  0.4260300099849701
# ----------------------------- 30
# sigma  0.7421303391456604
# mean  0.439695805311203
# ----------------------------- 40
# sigma  0.5528770685195923
# mean  0.48960962891578674
# ----------------------------- 50
# sigma  0.3805408775806427
# mean  0.518057644367218
# ----------------------------- 60
# sigma  0.21438153088092804
# mean  0.5158284902572632
# -------- final sigma,  0.09803483635187149
# -------- final mean  0.51206374168396
# -------- total number of iterations,  70 -------- average time per iteration (s),  0.0209
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0513588190078735
# mean  0.4098968803882599
# ----------------------------- 20
# sigma  0.9574316143989563
# mean  0.3930864632129669
# ----------------------------- 30
# sigma  0.7266125679016113
# mean  0.38528668880462646
# ----------------------------- 40
# sigma  0.546007513999939
# mean  0.40971148014068604
# ----------------------------- 50
# sigma  0.38694366812705994
# mean  0.3798764944076538
# ----------------------------- 60
# sigma  0.24582770466804504
# mean  0.3679254949092865
# ----------------------------- 70
# sigma  0.13427141308784485
# mean  0.3666471838951111
# -------- final sigma,  0.09417456388473511
# -------- final mean  0.371358722448349
# -------- total number of iterations,  76 -------- average time per iteration (s),  0.0214
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0442070960998535
# mean  0.4031163156032562
# ----------------------------- 20
# sigma  0.9017014503479004
# mean  0.3953630030155182
# ----------------------------- 30
# sigma  0.7778629064559937
# mean  0.39610669016838074
# ----------------------------- 40
# sigma  0.5447673201560974
# mean  0.4013979732990265
# ----------------------------- 50
# sigma  0.33574527502059937
# mean  0.3677295446395874
# ----------------------------- 60
# sigma  0.17627564072608948
# mean  0.35067445039749146
# -------- final sigma,  0.09849771112203598
# -------- final mean  0.3339988589286804
# -------- total number of iterations,  69 -------- average time per iteration (s),  0.0214
# --------- N :  100000
# ----------------------------- 10
# sigma  0.9949384927749634
# mean  0.40562671422958374
# ----------------------------- 20
# sigma  0.9005793333053589
# mean  0.39802077412605286
# ----------------------------- 30
# sigma  0.6504778861999512
# mean  0.4272518455982208
# ----------------------------- 40
# sigma  0.5048304796218872
# mean  0.3920111358165741
# ----------------------------- 50
# sigma  0.32520443201065063
# mean  0.3766293227672577
# ----------------------------- 60
# sigma  0.19906838238239288
# mean  0.3755541741847992
# ----------------------------- 70
# sigma  0.10446338355541229
# mean  0.3643099069595337
# -------- final sigma,  0.09891055524349213
# -------- final mean  0.36534401774406433
# -------- total number of iterations,  72 -------- average time per iteration (s),  0.0216
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0855114459991455
# mean  0.4393005073070526
# ----------------------------- 20
# sigma  0.9059613943099976
# mean  0.4729291498661041
# ----------------------------- 30
# sigma  0.7230666875839233
# mean  0.4236917793750763
# ----------------------------- 40
# sigma  0.5037286281585693
# mean  0.45242854952812195
# ----------------------------- 50
# sigma  0.35388022661209106
# mean  0.46386006474494934
# ----------------------------- 60
# sigma  0.20851317048072815
# mean  0.4681423604488373
# ----------------------------- 70
# sigma  0.10037605464458466
# mean  0.49007537961006165
# -------- final sigma,  0.09227431565523148
# -------- final mean  0.4890195429325104
# -------- total number of iterations,  72 -------- average time per iteration (s),  0.0215
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0650358200073242
# mean  0.41256946325302124
# ----------------------------- 20
# sigma  0.9208574295043945
# mean  0.4281703233718872
# ----------------------------- 30
# sigma  0.7005198001861572
# mean  0.41449034214019775
# ----------------------------- 40
# sigma  0.4840524196624756
# mean  0.3673843741416931
# ----------------------------- 50
# sigma  0.32276883721351624
# mean  0.3233250081539154
# ----------------------------- 60
# sigma  0.20483703911304474
# mean  0.31817883253097534
# ----------------------------- 70
# sigma  0.11581609398126602
# mean  0.3297485411167145
# -------- final sigma,  0.0938001349568367
# -------- final mean  0.32615765929222107
# -------- total number of iterations,  74 -------- average time per iteration (s),  0.0215
# --------- N :  100000
# ----------------------------- 10
# sigma  1.074368953704834
# mean  0.36011120676994324
# ----------------------------- 20
# sigma  0.8740041851997375
# mean  0.3335692882537842
# ----------------------------- 30
# sigma  0.7514019012451172
# mean  0.3125583529472351
# ----------------------------- 40
# sigma  0.5144738554954529
# mean  0.308485209941864
# ----------------------------- 50
# sigma  0.35224679112434387
# mean  0.2902531325817108
# ----------------------------- 60
# sigma  0.21519672870635986
# mean  0.25141045451164246
# ----------------------------- 70
# sigma  0.10944704711437225
# mean  0.24932700395584106
# -------- final sigma,  0.09526239335536957
# -------- final mean  0.2426525503396988
# -------- total number of iterations,  73 -------- average time per iteration (s),  0.022
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0341911315917969
# mean  0.4395935833454132
# ----------------------------- 20
# sigma  0.8913863897323608
# mean  0.4323296844959259
# ----------------------------- 30
# sigma  0.6973580121994019
# mean  0.40331459045410156
# ----------------------------- 40
# sigma  0.5196393728256226
# mean  0.442229300737381
# ----------------------------- 50
# sigma  0.35744524002075195
# mean  0.4760231375694275
# ----------------------------- 60
# sigma  0.22874358296394348
# mean  0.4904312789440155
# ----------------------------- 70
# sigma  0.13426725566387177
# mean  0.4885464608669281
# -------- final sigma,  0.09906473010778427
# -------- final mean  0.48500755429267883
# -------- total number of iterations,  75 -------- average time per iteration (s),  0.0228
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0825169086456299
# mean  0.4799153506755829
# ----------------------------- 20
# sigma  0.8924473524093628
# mean  0.42492735385894775
# ----------------------------- 30
# sigma  0.7328097820281982
# mean  0.36930906772613525
# ----------------------------- 40
# sigma  0.5660272240638733
# mean  0.3712823987007141
# ----------------------------- 50
# sigma  0.41165024042129517
# mean  0.34099632501602173
# ----------------------------- 60
# sigma  0.25367990136146545
# mean  0.32962679862976074
# ----------------------------- 70
# sigma  0.14982692897319794
# mean  0.336795836687088
# -------- final sigma,  0.0939941257238388
# -------- final mean  0.3316555321216583
# -------- total number of iterations,  77 -------- average time per iteration (s),  0.0215
# --------- N :  100000
# ----------------------------- 10
# sigma  1.084375262260437
# mean  0.45236507058143616
# ----------------------------- 20
# sigma  1.0063021183013916
# mean  0.40517792105674744
# ----------------------------- 30
# sigma  0.776866614818573
# mean  0.4591117203235626
# ----------------------------- 40
# sigma  0.6215903162956238
# mean  0.4194525480270386
# ----------------------------- 50
# sigma  0.4779152274131775
# mean  0.35887736082077026
# ----------------------------- 60
# sigma  0.2712467908859253
# mean  0.3778897821903229
# ----------------------------- 70
# sigma  0.14679217338562012
# mean  0.38567718863487244
# -------- final sigma,  0.0967126339673996
# -------- final mean  0.3893022835254669
# -------- total number of iterations,  77 -------- average time per iteration (s),  0.0222
# --------- N :  100000
# ----------------------------- 10
# sigma  1.0366499423980713
# mean  0.42722243070602417
# ----------------------------- 20
# sigma  0.8951814770698547
# mean  0.42493510246276855
# ----------------------------- 30
# sigma  0.7081266641616821
# mean  0.47577860951423645
# ----------------------------- 40
# sigma  0.4723583161830902
# mean  0.44821563363075256
# ----------------------------- 50
# sigma  0.31803885102272034
# mean  0.4307363033294678
# ----------------------------- 60
# sigma  0.15799936652183533
# mean  0.42496517300605774
# -------- final sigma,  0.09982983767986298
# -------- final mean  0.4261409044265747
# -------- total number of iterations,  67 -------- average time per iteration (s),  0.0212
# --- 71.92149949073792 seconds ---

# %%
show_im_set(all_samples['A'], n_columns=10 , label='generated by denoiser A')
show_im_set(all_samples['B'], n_columns=10 , label='generated by denoiser B')
